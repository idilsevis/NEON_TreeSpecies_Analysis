# %%
# ==== Kurulum & Yol Tanımları ====
from google.colab import drive
drive.mount('/content/drive', force_remount=True)

# ---- Dosya/dizin yolları----
BASE_NEON = "/content/drive/MyDrive/NEON_struct-plant"
BASE_NTE  = "/content/drive/MyDrive/weecology-NeonTreeEvaluation-d0b90bc"

ANN_DIR   = f"{BASE_NTE}/annotations"
ANN_WS    = f"{BASE_NTE}/annotations_with_species"
POLY_GPKG = f"{ANN_WS}/voc_polygons_with_species_FIXED.gpkg"

REPORT_DIR = f"{ANN_WS}/reports"
import os
os.makedirs(REPORT_DIR, exist_ok=True)

print("NEON:", BASE_NEON)
print("NTE :", BASE_NTE)
print("Reports ->", REPORT_DIR)
# Out:
# Mounted at /content/drive
# NEON: /content/drive/MyDrive/NEON_struct-plant
# NTE : /content/drive/MyDrive/weecology-NeonTreeEvaluation-d0b90bc
# Reports -> /content/drive/MyDrive/weecology-NeonTreeEvaluation-d0b90bc/annotations_with_species/reports

# %%
# ==== Kütüphaneler ====
# !pip -q install geopandas fiona shapely pyproj rtree

import os, re, glob, xml.etree.ElementTree as ET
import numpy as np
import pandas as pd
import geopandas as gpd
import fiona
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.6/56.6 kB 2.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.2/17.2 MB 61.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 507.6/507.6 kB 21.2 MB/s eta 0:00:00

# %%
# ==== NEON CSV kontrolü(örnekleme) ====
for root, dirs, files in os.walk(BASE_NEON):
    level = root.replace(BASE_NEON, "").count(os.sep)
    indent = " " * (2 * level)
    print(f"{indent}{os.path.basename(root) or '/'}")
    for f in files[:10]:
        print(f"{indent}  - {f}")

csvs = glob.glob(os.path.join(BASE_NEON, "**/*.csv"), recursive=True)
print("\nToplam CSV:", len(csvs))
print("Örnek 5:", [os.path.basename(c) for c in csvs[:5]])

# İlk 5 dosyadan kolon başlıklarını denetle
for c in csvs[:5]:
    try:
        df = pd.read_csv(c, nrows=1)
        print(f"\n--- {os.path.basename(c)} ---")
        print("Kolonlar:", list(df.columns))
    except Exception as e:
        print(f"\n--- {os.path.basename(c)} --- Hata:", e)
# Out:
# Streaming output truncated to the last 5000 lines.
#     - NEON.D02.BLAN.DP1.10098.001.vst_perplotperyear.2021-12.basic.20241118T073304Z.csv
#     - NEON.D02.BLAN.DP0.10098.001.categoricalCodes.20241118T073304Z.csv
#     - NEON.D02.BLAN.DP1.10098.001.EML.20211223-20211223.20250129T000730Z.xml
#     - NEON.D02.BLAN.DP1.10098.001.variables.20241118T073304Z.csv
#     - NEON.D02.BLAN.DP0.10098.001.validation.20241118T073304Z.csv
#   NEON.D07.GRSM.DP1.10098.001.2020-11.basic.20250129T000730Z.RELEASE-2025
#     - NEON.D07.GRSM.DP1.10098.001.EML.20201112-20201112.20250129T000730Z.xml
#     - NEON.D07.GRSM.DP1.10098.001.readme.20250129T000730Z.txt
#     - NEON.D07.GRSM.DP1.10098.001.vst_apparentindividual.2020-11.basic.20241118T160319Z.csv
#     - NEON.D07.GRSM.DP1.10098.001.vst_mappingandtagging.basic.20241118T160319Z.csv
#     - NEON.D07.GRSM.DP1.10098.001.vst_perplotperyear.2020-11.basic.20241118T160319Z.csv
#     - NEON.D07.GRSM.DP0.10098.001.validation.20241118T160319Z.csv
#     - NEON.D07.GRSM.DP0.10098.001.categoricalCodes.20241118T160319Z.csv
#     - NEON.D07.GRSM.DP1.10098.001.variables.20241118T160319Z.csv
#   NEON.D03.JERC.DP1.10098.001.2020-01.basic.20250129T000730Z.RELEASE-2025
#     - NEON.D03.JERC.DP1.10098.001.vst_mappingandtagging.basic.20241118T105905Z.csv
#     - NEON.D03.JERC.DP1.10098.001.readme.20250129T000730Z.txt
#     - NEON.D03.JERC.DP1.10098.001.vst_perplotperyear.2020-01.basic.20241118T105905Z.csv
#     - NEON.D03.JERC.DP1.10098.001.vst_apparentindividual.2020-01.basic.20241118T105905Z.csv
#     - NEON.D03.JERC.DP0.10098.001.validation.20241118T105905Z.csv
#     - NEON.D03.JERC.DP0.10098.001.categoricalCodes.20241118T105905Z.csv
#     - NEON.D03.JERC.DP1.10098.001.EML.20200107-20200122.20250129T000730Z.xml
#     - NEON.D03.JERC.DP1.10098.001.variables.20241118T105905Z.csv
#   NEON.D07.ORNL.DP1.10098.001.2017-11.basic.20250129T000730Z.RELEASE-2025
#     - NEON.D07.ORNL.DP0.10098.001.categoricalCodes.20241118T043730Z.csv
#     - NEON.D07.ORNL.DP1.10098.001.vst_apparentindividual.2017-11.basic.20241118T043730Z.csv
#     - NEON.D07.ORNL.DP1.10098.001.vst_perplotperyear.2017-11.basic.20241118T043730Z.csv
#     - NEON.D07.ORNL.DP1.10098.001.readme.20250129T000730Z.txt
#     - NEON.D07.ORNL.DP1.10098.001.vst_shrubgroup.2017-11.basic.20241118T043730Z.csv
#     - NEON.D07.ORNL.DP1.10098.001.variables.20241118T043730Z.csv
#     - NEON.D07.ORNL.DP1.10098.001.vst_mappingandtagging.basic.20241118T043730Z.csv
#     - NEON.D07.ORNL.DP1.10098.001.EML.20171107-20171116.20250129T000730Z.xml
#     - NEON.D07.ORNL.DP0.10098.001.validation.20241118T043730Z.csv
#   NEON.D06.KONZ.DP1.10098.001.2021-03.basic.20250129T000730Z.RELEASE-2025
#     - NEON.D06.KONZ.DP0.10098.001.validation.20241118T194522Z.csv
#     - NEON.D06.KONZ.DP1.10098.001.readme.20250129T000730Z.txt
#     - NEON.D06.KONZ.DP1.10098.001.variables.20241118T194522Z.csv
#     - NEON.D06.KONZ.DP1.10098.001.EML.20210325-20210329.20250129T000730Z.xml
#     - NEON.D06.KONZ.DP1.10098.001.vst_apparentindividual.2021-03.basic.20241118T194522Z.csv
#     - NEON.D06.KONZ.DP1.10098.001.vst_mappingandtagging.basic.20241118T194522Z.csv
#     - NEON.D06.KONZ.DP0.10098.001.categoricalCodes.20241118T194522Z.csv
#   NEON.D17.SJER.DP1.10098.001.2023-11.basic.20250129T000730Z.RELEASE-2025
#     - NEON.D17.SJER.DP1.10098.001.vst_perplotperyear.2023-11.basic.20241118T140250Z.csv
#     - NEON.D17.SJER.DP1.10098.001.readme.20250129T000730Z.txt
#     - NEON.D17.SJER.DP0.10098.001.categoricalCodes.20241118T140250Z.csv
#     - NEON.D17.SJER.DP1.10098.001.variables.20241118T140250Z.csv
#     - NEON.D17.SJER.DP1.10098.001.EML.20231129-20231129.20250129T000730Z.xml
#     - NEON.D17.SJER.DP1.10098.001.vst_apparentindividual.2023-11.basic.20241118T140250Z.csv
#     - NEON.D17.SJER.DP0.10098.001.validation.20241118T140250Z.csv
#     - NEON.D17.SJER.DP1.10098.001.vst_mappingandtagging.basic.20241118T140250Z.csv
#   NEON.D16.WREF.DP1.10098.001.2020-04.basic.20250129T000730Z.RELEASE-2025
#     - NEON.D16.WREF.DP0.10098.001.validation.20250122T230356Z.csv
#     - NEON.D16.WREF.DP1.10098.001.vst_apparentindividual.2020-04.basic.20250122T230356Z.csv
#     - NEON.D16.WREF.DP1.10098.001.readme.20250129T000730Z.txt
#     - NEON.D16.WREF.DP1.10098.001.vst_mappingandtagging.basic.20250122T230356Z.csv
#     - NEON.D16.WREF.DP0.10098.001.categoricalCodes.20250122T230356Z.csv
#     - NEON.D16.WREF.DP1.10098.001.variables.20250122T230356Z.csv
#     - NEON.D16.WREF.DP1.10098.001.EML.20200405-20200405.20250129T000730Z.xml
#   NEON.D14.SRER.DP1.10098.001.2021-04.basic.20250129T000730Z.RELEASE-2025
#     - NEON.D14.SRER.DP0.10098.001.categoricalCodes.20241118T033620Z.csv
#     - NEON.D14.SRER.DP1.10098.001.readme.20250129T000730Z.txt
#     - NEON.D14.SRER.DP0.10098.001.validation.20241118T033620Z.csv
#     - NEON.D14.SRER.DP1.10098.001.vst_non-woody.2021-04.basic.20241118T033620Z.csv
#     - NEON.D14.SRER.DP1.10098.001.vst_perplotperyear.2021-04.basic.20241118T033620Z.csv
#     - NEON.D14.SRER.DP1.10098.001.EML.20210427-20210429.20250129T000730Z.xml
#     - NEON.D14.SRER.DP1.10098.001.vst_mappingandtagging.basic.20241118T033620Z.csv
#     - NEON.D14.SRER.DP1.10098.001.variables.20241118T033620Z.csv
#   NEON.D07.ORNL.DP1.10098.001.2020-06.basic.20250129T000730Z.RELEASE-2025
#     - NEON.D07.ORNL.DP1.10098.001.variables.20241118T065419Z.csv
#     - NEON.D07.ORNL.DP1.10098.001.EML.20200603-20200608.20250129T000730Z.xml
#     - NEON.D07.ORNL.DP1.10098.001.vst_perplotperyear.2020-06.basic.20241118T065419Z.csv
#     - NEON.D07.ORNL.DP0.10098.001.validation.20241118T065419Z.csv
#     - NEON.D07.ORNL.DP1.10098.001.readme.20250129T000730Z.txt
#     - NEON.D07.ORNL.DP0.10098.001.categoricalCodes.20241118T065419Z.csv
#     - NEON.D07.ORNL.DP1.10098.001.vst_mappingandtagging.basic.20241118T065419Z.csv
#   NEON.D05.UNDE.DP1.10098.001.2022-09.basic.20250129T000730Z.RELEASE-2025
#     - NEON.D05.UNDE.DP1.10098.001.vst_mappingandtagging.basic.20241118T065150Z.csv
#     - NEON.D05.UNDE.DP1.10098.001.variables.20241118T065150Z.csv
#     - NEON.D05.UNDE.DP1.10098.001.EML.20220908-20220929.20250129T000730Z.xml
#     - NEON.D05.UNDE.DP1.10098.001.readme.20250129T000730Z.txt
#     - NEON.D05.UNDE.DP0.10098.001.validation.20241118T065150Z.csv
#     - NEON.D05.UNDE.DP1.10098.001.vst_apparentindividual.2022-09.basic.20241118T065150Z.csv
#     - NEON.D05.UNDE.DP0.10098.001.categoricalCodes.20241118T065150Z.csv
#   NEON.D11.CLBJ.DP1.10098.001.2021-11.basic.20250129T000730Z.RELEASE-2025
#     - NEON.D11.CLBJ.DP0.10098.001.validation.20241118T050654Z.csv
#     - NEON.D11.CLBJ.DP1.10098.001.vst_non-woody.2021-11.basic.20241118T050654Z.csv
#     - NEON.D11.CLBJ.DP1.10098.001.vst_perplotperyear.2021-11.basic.20241118T050654Z.csv
#     - NEON.D11.CLBJ.DP1.10098.001.variables.20241118T050654Z.csv
#     - NEON.D11.CLBJ.DP0.10098.001.categoricalCodes.20241118T050654Z.csv
#     - NEON.D11.CLBJ.DP1.10098.001.vst_mappingandtagging.basic.20241118T050654Z.csv
#     - NEON.D11.CLBJ.DP1.10098.001.readme.20250129T000730Z.txt
#     - NEON.D11.CLBJ.DP1.10098.001.vst_apparentindividual.2021-11.basic.20241118T050654Z.csv
#     - NEON.D11.CLBJ.DP1.10098.001.EML.20211122-20211130.20250129T000730Z.xml
#   NEON.D08.TALL.DP1.10098.001.2017-12.basic.20250129T000730Z.RELEASE-2025
#     - NEON.D08.TALL.DP1.10098.001.EML.20171207-20171221.20250129T000730Z.xml
#     - NEON.D08.TALL.DP0.10098.001.categoricalCodes.20241118T151729Z.csv
#     - NEON.D08.TALL.DP1.10098.001.vst_perplotperyear.2017-12.basic.20241118T151729Z.csv
#     - NEON.D08.TALL.DP1.10098.001.vst_mappingandtagging.basic.20241118T151729Z.csv
#     - NEON.D08.TALL.DP1.10098.001.variables.20241118T151729Z.csv
#     - NEON.D08.TALL.DP0.10098.001.validation.20241118T151729Z.csv
#     - NEON.D08.TALL.DP1.10098.001.readme.20250129T000730Z.txt
#     - NEON.D08.TALL.DP1.10098.001.vst_apparentindividual.2017-12.basic.20241118T151729Z.csv
#   NEON.D04.GUAN.DP1.10098.001.2021-01.basic.20250129T000730Z.RELEASE-2025
#     - NEON.D04.GUAN.DP1.10098.001.vst_apparentindividual.2021-01.basic.20241118T070809Z.csv
#     - NEON.D04.GUAN.DP1.10098.001.vst_non-woody.2021-01.basic.20241118T070809Z.csv
#     - NEON.D04.GUAN.DP0.10098.001.categoricalCodes.20241118T070809Z.csv
#     - NEON.D04.GUAN.DP1.10098.001.vst_mappingandtagging.basic.20241118T070809Z.csv
#     - NEON.D04.GUAN.DP1.10098.001.EML.20210118-20210126.20250129T000730Z.xml
#     - NEON.D04.GUAN.DP0.10098.001.validation.20241118T070809Z.csv
#     - NEON.D04.GUAN.DP1.10098.001.variables.20241118T070809Z.csv
#     - NEON.D04.GUAN.DP1.10098.001.readme.20250129T000730Z.txt
#     - NEON.D04.GUAN.DP1.10098.001.vst_perplotperyear.2021-01.basic.20241118T070809Z.csv
#   NEON.D06.UKFS.DP1.10098.001.2021-11.basic.20250129T000730Z.RELEASE-2025
#     - NEON.D06.UKFS.DP1.10098.001.vst_mappingandtagging.basic.20241118T051438Z.csv
#     - NEON.D06.UKFS.DP1.10098.001.vst_perplotperyear.2021-11.basic.20241118T051438Z.csv
#     - NEON.D06.UKFS.DP1.10098.001.variables.20241118T051438Z.csv
#     - NEON.D06.UKFS.DP1.10098.001.readme.20250129T000730Z.txt
#     - NEON.D06.UKFS.DP0.10098.001.categoricalCodes.20241118T051438Z.csv
#     - NEON.D06.UKFS.DP1.10098.001.EML.20211101-20211111.20250129T000730Z.xml
#     - NEON.D06.UKFS.DP1.10098.001.vst_apparentindividual.2021-11.basic.20241118T051438Z.csv
#     - NEON.D06.UKFS.DP0.10098.001.validation.20241118T051438Z.csv
#   NEON.D08.DELA.DP1.10098.001.2020-12.basic.20250129T000730Z.RELEASE-2025
#     - NEON.D08.DELA.DP1.10098.001.vst_perplotperyear.2020-12.basic.20241118T013418Z.csv
#     - NEON.D08.DELA.DP1.10098.001.readme.20250129T000730Z.txt
#     - NEON.D08.DELA.DP1.10098.001.vst_mappingandtagging.basic.20241118T013418Z.csv
#     - NEON.D08.DELA.DP1.10098.001.EML.20201203-20201210.20250129T000730Z.xml
#     - NEON.D08.DELA.DP0.10098.001.validation.20241118T013418Z.csv
#     - NEON.D08.DELA.DP1.10098.001.vst_apparentindividual.2020-12.basic.20241118T013418Z.csv
#     - NEON.D08.DELA.DP0.10098.001.categoricalCodes.20241118T013418Z.csv
#     - NEON.D08.DELA.DP1.10098.001.variables.20241118T013418Z.csv
#   NEON.D05.UNDE.DP1.10098.001.2019-08.basic.20250129T000730Z.RELEASE-2025
#     - NEON.D05.UNDE.DP0.10098.001.validation.20241118T184409Z.csv
#     - NEON.D05.UNDE.DP1.10098.001.vst_mappingandtagging.basic.20241118T184409Z.csv
#     - NEON.D05.UNDE.DP1.10098.001.variables.20241118T184409Z.csv
#     - NEON.D05.UNDE.DP1.10098.001.vst_non-woody.2019-08.basic.20241118T184409Z.csv
#     - NEON.D05.UNDE.DP1.10098.001.vst_perplotperyear.2019-08.basic.20241118T184409Z.csv
#     - NEON.D05.UNDE.DP1.10098.001.EML.20190801-20190812.20250129T000730Z.xml
#     - NEON.D05.UNDE.DP1.10098.001.readme.20250129T000730Z.txt
#     - NEON.D05.UNDE.DP0.10098.001.categoricalCodes.20241118T184409Z.csv
#   NEON.D20.PUUM.DP1.10098.001.2020-11.basic.20250129T000730Z.RELEASE-2025
#     - NEON.D20.PUUM.DP1.10098.001.vst_apparentindividual.2020-11.basic.20241118T045421Z.csv
#     - NEON.D20.PUUM.DP1.10098.001.readme.20250129T000730Z.txt
#     - NEON.D20.PUUM.DP1.10098.001.vst_mappingandtagging.basic.20241118T045421Z.csv
#     - NEON.D20.PUUM.DP1.10098.001.EML.20201103-20201112.20250129T000730Z.xml
#     - NEON.D20.PUUM.DP1.10098.001.vst_non-woody.2020-11.basic.20241118T045421Z.csv
#     - NEON.D20.PUUM.DP1.10098.001.vst_perplotperyear.2020-11.basic.20241118T045421Z.csv
#     - NEON.D20.PUUM.DP0.10098.001.categoricalCodes.20241118T045421Z.csv
#     - NEON.D20.PUUM.DP1.10098.001.variables.20241118T045421Z.csv
#     - NEON.D20.PUUM.DP0.10098.001.validation.20241118T045421Z.csv
#   NEON.D01.BART.DP1.10098.001.2020-08.basic.20250129T000730Z.RELEASE-2025
#     - NEON.D01.BART.DP1.10098.001.vst_perplotperyear.2020-08.basic.20241118T171301Z.csv
#     - NEON.D01.BART.DP0.10098.001.categoricalCodes.20241118T171301Z.csv
#     - NEON.D01.BART.DP0.10098.001.validation.20241118T171301Z.csv
#     - NEON.D01.BART.DP1.10098.001.EML.20200805-20200823.20250129T000730Z.xml
#     - NEON.D01.BART.DP1.10098.001.vst_mappingandtagging.basic.20241118T171301Z.csv
#     - NEON.D01.BART.DP1.10098.001.variables.20241118T171301Z.csv
#     - NEON.D01.BART.DP1.10098.001.readme.20250129T000730Z.txt
#     - NEON.D01.BART.DP1.10098.001.vst_apparentindividual.2020-08.basic.20241118T171301Z.csv
#   NEON.D07.ORNL.DP1.10098.001.2022-02.basic.20250129T000730Z.RELEASE-2025
#     - NEON.D07.ORNL.DP0.10098.001.categoricalCodes.20241118T105905Z.csv
#     - NEON.D07.ORNL.DP1.10098.001.readme.20250129T000730Z.txt
#     - NEON.D07.ORNL.DP1.10098.001.vst_apparentindividual.2022-02.basic.20241118T105905Z.csv
#     - NEON.D07.ORNL.DP1.10098.001.EML.20220202-20220209.20250129T000730Z.xml
#     - NEON.D07.ORNL.DP1.10098.001.variables.20241118T105905Z.csv
#     - NEON.D07.ORNL.DP0.10098.001.validation.20241118T105905Z.csv
#     - NEON.D07.ORNL.DP1.10098.001.vst_mappingandtagging.basic.20241118T105905Z.csv
#     - NEON.D07.ORNL.DP1.10098.001.vst_perplotperyear.2022-02.basic.20241118T105905Z.csv
#   NEON.D19.DEJU.DP1.10098.001.2020-09.basic.20250129T000730Z.RELEASE-2025
#     - NEON.D19.DEJU.DP0.10098.001.validation.20241118T135429Z.csv
#     - NEON.D19.DEJU.DP0.10098.001.categoricalCodes.20241118T135429Z.csv
#     - NEON.D19.DEJU.DP1.10098.001.vst_mappingandtagging.basic.20241118T135429Z.csv
#     - NEON.D19.DEJU.DP1.10098.001.readme.20250129T000730Z.txt
#     - NEON.D19.DEJU.DP1.10098.001.EML.20200908-20200910.20250129T000730Z.xml
#     - NEON.D19.DEJU.DP1.10098.001.variables.20241118T135429Z.csv
#     - NEON.D19.DEJU.DP1.10098.001.vst_apparentindividual.2020-09.basic.20241118T135429Z.csv
#   NEON.D06.UKFS.DP1.10098.001.2017-01.basic.20250129T000730Z.RELEASE-2025
#     - NEON.D06.UKFS.DP1.10098.001.vst_mappingandtagging.basic.20241118T011512Z.csv
#     - NEON.D06.UKFS.DP1.10098.001.EML.20170103-20170105.20250129T000730Z.xml
#     - NEON.D06.UKFS.DP1.10098.001.readme.20250129T000730Z.txt
#     - NEON.D06.UKFS.DP0.10098.001.categoricalCodes.20241118T011512Z.csv
#     - NEON.D06.UKFS.DP1.10098.001.vst_apparentindividual.2017-01.basic.20241118T011512Z.csv
#     - NEON.D06.UKFS.DP0.10098.001.validation.20241118T011512Z.csv
#     - NEON.D06.UKFS.DP1.10098.001.variables.20241118T011512Z.csv
#   NEON.D04.GUAN.DP1.10098.001.2020-06.basic.20250129T000730Z.RELEASE-2025
#     - NEON.D04.GUAN.DP1.10098.001.vst_mappingandtagging.basic.20241118T184027Z.csv
#     - NEON.D04.GUAN.DP1.10098.001.vst_perplotperyear.2020-06.basic.20241118T184027Z.csv
#     - NEON.D04.GUAN.DP1.10098.001.vst_non-woody.2020-06.basic.20241118T184027Z.csv
#     - NEON.D04.GUAN.DP1.10098.001.vst_apparentindividual.2020-06.basic.20241118T184027Z.csv
#     - NEON.D04.GUAN.DP1.10098.001.readme.20250129T000730Z.txt
#     - NEON.D04.GUAN.DP1.10098.001.variables.20241118T184027Z.csv
#     - NEON.D04.GUAN.DP1.10098.001.EML.20200615-20200630.20250129T000730Z.xml
#     - NEON.D04.GUAN.DP0.10098.001.validation.20241118T184027Z.csv
#     - NEON.D04.GUAN.DP0.10098.001.categoricalCodes.20241118T184027Z.csv
#   NEON.D16.ABBY.DP1.10098.001.2023-08.basic.20250129T000730Z.RELEASE-2025
#     - NEON.D16.ABBY.DP1.10098.001.vst_perplotperyear.2023-08.basic.20250122T231936Z.csv
#     - NEON.D16.ABBY.DP1.10098.001.vst_apparentindividual.2023-08.basic.20250122T231936Z.csv
#     - NEON.D16.ABBY.DP0.10098.001.categoricalCodes.20250122T231936Z.csv
#     - NEON.D16.ABBY.DP1.10098.001.vst_mappingandtagging.basic.20250122T231936Z.csv
#     - NEON.D16.ABBY.DP0.10098.001.validation.20250122T231936Z.csv
#     - NEON.D16.ABBY.DP1.10098.001.EML.20230828-20230829.20250129T000730Z.xml
#     - NEON.D16.ABBY.DP1.10098.001.readme.20250129T000730Z.txt
#     - NEON.D16.ABBY.DP1.10098.001.variables.20250122T231936Z.csv
#   NEON.D16.WREF.DP1.10098.001.2020-08.basic.20250129T000730Z.RELEASE-2025
#     - NEON.D16.WREF.DP0.10098.001.categoricalCodes.20250122T230651Z.csv
#     - NEON.D16.WREF.DP1.10098.001.readme.20250129T000730Z.txt
#     - NEON.D16.WREF.DP1.10098.001.variables.20250122T230651Z.csv
#     - NEON.D16.WREF.DP1.10098.001.vst_non-woody.2020-08.basic.20250122T230651Z.csv
#     - NEON.D16.WREF.DP1.10098.001.vst_mappingandtagging.basic.20250122T230651Z.csv
#     - NEON.D16.WREF.DP1.10098.001.EML.20200827-20200829.20250129T000730Z.xml
#     - NEON.D16.WREF.DP0.10098.001.validation.20250122T230651Z.csv
#   NEON.D19.BONA.DP1.10098.001.2021-09.basic.20250129T000730Z.RELEASE-2025
#     - NEON.D19.BONA.DP0.10098.001.categoricalCodes.20241118T141342Z.csv
#     - NEON.D19.BONA.DP1.10098.001.vst_perplotperyear.2021-09.basic.20241118T141342Z.csv
#     - NEON.D19.BONA.DP1.10098.001.vst_mappingandtagging.basic.20241118T141342Z.csv
#     - NEON.D19.BONA.DP1.10098.001.EML.20210907-20210909.20250129T000730Z.xml
#     - NEON.D19.BONA.DP0.10098.001.validation.20241118T141342Z.csv
#     - NEON.D19.BONA.DP1.10098.001.variables.20241118T141342Z.csv
#     - NEON.D19.BONA.DP1.10098.001.readme.20250129T000730Z.txt
#     - NEON.D19.BONA.DP1.10098.001.vst_apparentindividual.2021-09.basic.20241118T141342Z.csv
#   NEON.D10.RMNP.DP1.10098.001.2021-10.basic.20250129T000730Z.RELEASE-2025
#     - NEON.D10.RMNP.DP1.10098.001.variables.20241118T010737Z.csv
#     - NEON.D10.RMNP.DP1.10098.001.vst_apparentindividual.2021-10.basic.20241118T010737Z.csv
#     - NEON.D10.RMNP.DP0.10098.001.categoricalCodes.20241118T010737Z.csv
#     - NEON.D10.RMNP.DP1.10098.001.EML.20211005-20211014.20250129T000730Z.xml
#     - NEON.D10.RMNP.DP1.10098.001.readme.20250129T000730Z.txt
#     - NEON.D10.RMNP.DP0.10098.001.validation.20241118T010737Z.csv
#     - NEON.D10.RMNP.DP1.10098.001.vst_mappingandtagging.basic.20241118T010737Z.csv
#     - NEON.D10.RMNP.DP1.10098.001.vst_perplotperyear.2021-10.basic.20241118T010737Z.csv
#   NEON.D08.DELA.DP1.10098.001.2018-10.basic.20250129T000730Z.RELEASE-2025
#     - NEON.D08.DELA.DP0.10098.001.validation.20241118T024951Z.csv
#     - NEON.D08.DELA.DP1.10098.001.vst_perplotperyear.2018-10.basic.20241118T024951Z.csv
#     - NEON.D08.DELA.DP1.10098.001.variables.20241118T024951Z.csv
#     - NEON.D08.DELA.DP1.10098.001.readme.20250129T000730Z.txt
#     - NEON.D08.DELA.DP1.10098.001.vst_mappingandtagging.basic.20241118T024951Z.csv
#     - NEON.D08.DELA.DP1.10098.001.vst_apparentindividual.2018-10.basic.20241118T024951Z.csv
#     - NEON.D08.DELA.DP1.10098.001.EML.20181024-20181030.20250129T000730Z.xml
#     - NEON.D08.DELA.DP0.10098.001.categoricalCodes.20241118T024951Z.csv
#   NEON.D02.SCBI.DP1.10098.001.2017-11.basic.20250129T000730Z.RELEASE-2025
#     - NEON.D02.SCBI.DP0.10098.001.categoricalCodes.20241118T043920Z.csv
#     - NEON.D02.SCBI.DP1.10098.001.vst_shrubgroup.2017-11.basic.20241118T043920Z.csv
#     - NEON.D02.SCBI.DP1.10098.001.vst_perplotperyear.2017-11.basic.20241118T043920Z.csv
#     - NEON.D02.SCBI.DP1.10098.001.EML.20171101-20171130.20250129T000730Z.xml
#     - NEON.D02.SCBI.DP0.10098.001.validation.20241118T043920Z.csv
#     - NEON.D02.SCBI.DP1.10098.001.variables.20241118T043920Z.csv
#     - NEON.D02.SCBI.DP1.10098.001.vst_mappingandtagging.basic.20241118T043920Z.csv
#     - NEON.D02.SCBI.DP1.10098.001.readme.20250129T000730Z.txt
#     - NEON.D02.SCBI.DP1.10098.001.vst_apparentindividual.2017-11.basic.20241118T043920Z.csv
#   NEON.D16.ABBY.DP1.10098.001.2018-09.basic.20250129T000730Z.RELEASE-2025
#     - NEON.D16.ABBY.DP0.10098.001.validation.20250122T230246Z.csv
#     - NEON.D16.ABBY.DP1.10098.001.readme.20250129T000730Z.txt
#     - NEON.D16.ABBY.DP0.10098.001.categoricalCodes.20250122T230246Z.csv
#     - NEON.D16.ABBY.DP1.10098.001.EML.20180928-20180928.20250129T000730Z.xml
#     - NEON.D16.ABBY.DP1.10098.001.vst_apparentindividual.2018-09.basic.20250122T230246Z.csv
#     - NEON.D16.ABBY.DP1.10098.001.variables.20250122T230246Z.csv
#     - NEON.D16.ABBY.DP1.10098.001.vst_mappingandtagging.basic.20250122T230246Z.csv
#   NEON.D02.SCBI.DP1.10098.001.2023-09.basic.20250129T000730Z.RELEASE-2025
#     - NEON.D02.SCBI.DP1.10098.001.readme.20250129T000730Z.txt
#     - NEON.D02.SCBI.DP1.10098.001.vst_apparentindividual.2023-09.basic.20241118T031715Z.csv
#     - NEON.D02.SCBI.DP1.10098.001.EML.20230920-20230928.20250129T000730Z.xml
#     - NEON.D02.SCBI.DP1.10098.001.variables.20241118T031715Z.csv
#     - NEON.D02.SCBI.DP1.10098.001.vst_perplotperyear.2023-09.basic.20241118T031715Z.csv
#     - NEON.D02.SCBI.DP0.10098.001.categoricalCodes.20241118T031715Z.csv
#     - NEON.D02.SCBI.DP1.10098.001.vst_mappingandtagging.basic.20241118T031715Z.csv
#     - NEON.D02.SCBI.DP0.10098.001.validation.20241118T031715Z.csv
#   NEON.D04.GUAN.DP1.10098.001.2022-02.basic.20250129T000730Z.RELEASE-2025
#     - NEON.D04.GUAN.DP0.10098.001.validation.20241118T091633Z.csv
#     - NEON.D04.GUAN.DP1.10098.001.vst_mappingandtagging.basic.20241118T091633Z.csv
#     - NEON.D04.GUAN.DP1.10098.001.vst_apparentindividual.2022-02.basic.20241118T091633Z.csv
#     - NEON.D04.GUAN.DP0.10098.001.categoricalCodes.20241118T091633Z.csv
#     - NEON.D04.GUAN.DP1.10098.001.variables.20241118T091633Z.csv
#     - NEON.D04.GUAN.DP1.10098.001.vst_perplotperyear.2022-02.basic.20241118T091633Z.csv
#     - NEON.D04.GUAN.DP1.10098.001.vst_non-woody.2022-02.basic.20241118T091633Z.csv
#     - NEON.D04.GUAN.DP1.10098.001.EML.20220201-20220224.20250129T000730Z.xml
#     - NEON.D04.GUAN.DP1.10098.001.readme.20250129T000730Z.txt
#   NEON.D02.BLAN.DP1.10098.001.2019-10.basic.20250129T000730Z.RELEASE-2025
#     - NEON.D02.BLAN.DP1.10098.001.EML.20191001-20191003.20250129T000730Z.xml
#     - NEON.D02.BLAN.DP1.10098.001.vst_shrubgroup.2019-10.basic.20241118T100420Z.csv
#     - NEON.D02.BLAN.DP1.10098.001.readme.20250129T000730Z.txt
#     - NEON.D02.BLAN.DP1.10098.001.vst_apparentindividual.2019-10.basic.20241118T100420Z.csv
#     - NEON.D02.BLAN.DP1.10098.001.vst_perplotperyear.2019-10.basic.20241118T100420Z.csv
#     - NEON.D02.BLAN.DP0.10098.001.categoricalCodes.20241118T100420Z.csv
#     - NEON.D02.BLAN.DP0.10098.001.validation.20241118T100420Z.csv
#     - NEON.D02.BLAN.DP1.10098.001.vst_mappingandtagging.basic.20241118T100420Z.csv
#     - NEON.D02.BLAN.DP1.10098.001.variables.20241118T100420Z.csv
#   NEON.D13.NIWO.DP1.10098.001.2019-09.basic.20250129T000730Z.RELEASE-2025
#     - NEON.D13.NIWO.DP1.10098.001.readme.20250129T000730Z.txt
#     - NEON.D13.NIWO.DP1.10098.001.variables.20241118T180505Z.csv
#     - NEON.D13.NIWO.DP0.10098.001.categoricalCodes.20241118T180505Z.csv
#     - NEON.D13.NIWO.DP1.10098.001.vst_mappingandtagging.basic.20241118T180505Z.csv
#     - NEON.D13.NIWO.DP1.10098.001.vst_apparentindividual.2019-09.basic.20241118T180505Z.csv
#     - NEON.D13.NIWO.DP1.10098.001.vst_perplotperyear.2019-09.basic.20241118T180505Z.csv
#     - NEON.D13.NIWO.DP0.10098.001.validation.20241118T180505Z.csv
#     - NEON.D13.NIWO.DP1.10098.001.EML.20190905-20190930.20250129T000730Z.xml
#   NEON.D03.OSBS.DP1.10098.001.2018-05.basic.20250129T000730Z.RELEASE-2025
#     - NEON.D03.OSBS.DP1.10098.001.vst_mappingandtagging.basic.20241118T151828Z.csv
#     - NEON.D03.OSBS.DP1.10098.001.EML.20180503-20180507.20250129T000730Z.xml
#     - NEON.D03.OSBS.DP1.10098.001.vst_non-woody.2018-05.basic.20241118T151828Z.csv
#     - NEON.D03.OSBS.DP0.10098.001.categoricalCodes.20241118T151828Z.csv
#     - NEON.D03.OSBS.DP1.10098.001.readme.20250129T000730Z.txt
#     - NEON.D03.OSBS.DP1.10098.001.vst_perplotperyear.2018-05.basic.20241118T151828Z.csv
#     - NEON.D03.OSBS.DP1.10098.001.variables.20241118T151828Z.csv
#     - NEON.D03.OSBS.DP0.10098.001.validation.20241118T151828Z.csv
#   NEON.D01.HARV.DP1.10098.001.2023-09.basic.20250129T000730Z.RELEASE-2025
#     - NEON.D01.HARV.DP0.10098.001.validation.20241118T023200Z.csv
#     - NEON.D01.HARV.DP1.10098.001.readme.20250129T000730Z.txt
#     - NEON.D01.HARV.DP1.10098.001.variables.20241118T023200Z.csv
#     - NEON.D01.HARV.DP1.10098.001.vst_apparentindividual.2023-09.basic.20241118T023200Z.csv
#     - NEON.D01.HARV.DP1.10098.001.vst_mappingandtagging.basic.20241118T023200Z.csv
#     - NEON.D01.HARV.DP0.10098.001.categoricalCodes.20241118T023200Z.csv
#     - NEON.D01.HARV.DP1.10098.001.EML.20230912-20230914.20250129T000730Z.xml
#   NEON.D16.WREF.DP1.10098.001.2021-03.basic.20250129T000730Z.RELEASE-2025
#     - NEON.D16.WREF.DP1.10098.001.vst_apparentindividual.2021-03.basic.20250122T230154Z.csv
#     - NEON.D16.WREF.DP1.10098.001.EML.20210301-20210330.20250129T000730Z.xml
#     - NEON.D16.WREF.DP0.10098.001.categoricalCodes.20250122T230154Z.csv
#     - NEON.D16.WREF.DP1.10098.001.readme.20250129T000730Z.txt
#     - NEON.D16.WREF.DP1.10098.001.vst_mappingandtagging.basic.20250122T230154Z.csv
#     - NEON.D16.WREF.DP1.10098.001.variables.20250122T230154Z.csv
#     - NEON.D16.WREF.DP0.10098.001.validation.20250122T230154Z.csv
#   NEON.D04.GUAN.DP1.10098.001.2017-02.basic.20250129T000730Z.RELEASE-2025
#     - NEON.D04.GUAN.DP1.10098.001.vst_mappingandtagging.basic.20241118T181926Z.csv
#     - NEON.D04.GUAN.DP0.10098.001.categoricalCodes.20241118T181926Z.csv
#     - NEON.D04.GUAN.DP0.10098.001.validation.20241118T181926Z.csv
#     - NEON.D04.GUAN.DP1.10098.001.readme.20250129T000730Z.txt
#     - NEON.D04.GUAN.DP1.10098.001.vst_apparentindividual.2017-02.basic.20241118T181926Z.csv
#     - NEON.D04.GUAN.DP1.10098.001.vst_perplotperyear.2017-02.basic.20241118T181926Z.csv
#     - NEON.D04.GUAN.DP1.10098.001.variables.20241118T181926Z.csv
#     - NEON.D04.GUAN.DP1.10098.001.EML.20170227-20170227.20250129T000730Z.xml
#   NEON.D11.CLBJ.DP1.10098.001.2017-12.basic.20250129T000730Z.RELEASE-2025
#     - NEON.D11.CLBJ.DP0.10098.001.categoricalCodes.20241118T095806Z.csv
#     - NEON.D11.CLBJ.DP1.10098.001.variables.20241118T095806Z.csv
#     - NEON.D11.CLBJ.DP1.10098.001.EML.20171204-20171221.20250129T000730Z.xml
#     - NEON.D11.CLBJ.DP1.10098.001.vst_apparentindividual.2017-12.basic.20241118T095806Z.csv
#     - NEON.D11.CLBJ.DP1.10098.001.readme.20250129T000730Z.txt
#     - NEON.D11.CLBJ.DP0.10098.001.validation.20241118T095806Z.csv
#     - NEON.D11.CLBJ.DP1.10098.001.vst_mappingandtagging.basic.20241118T095806Z.csv
#     - NEON.D11.CLBJ.DP1.10098.001.vst_perplotperyear.2017-12.basic.20241118T095806Z.csv
#   NEON.D02.SCBI.DP1.10098.001.2022-11.basic.20250129T000730Z.RELEASE-2025
#     - NEON.D02.SCBI.DP1.10098.001.vst_apparentindividual.2022-11.basic.20241118T202730Z.csv
#     - NEON.D02.SCBI.DP1.10098.001.readme.20250129T000730Z.txt
#     - NEON.D02.SCBI.DP0.10098.001.categoricalCodes.20241118T202730Z.csv
#     - NEON.D02.SCBI.DP1.10098.001.variables.20241118T202730Z.csv
#     - NEON.D02.SCBI.DP1.10098.001.vst_mappingandtagging.basic.20241118T202730Z.csv
#     - NEON.D02.SCBI.DP1.10098.001.vst_perplotperyear.2022-11.basic.20241118T202730Z.csv
#     - NEON.D02.SCBI.DP1.10098.001.EML.20221102-20221110.20250129T000730Z.xml
#     - NEON.D02.SCBI.DP0.10098.001.validation.20241118T202730Z.csv
#   NEON.D16.ABBY.DP1.10098.001.2019-11.basic.20250129T000730Z.RELEASE-2025
#     - NEON.D16.ABBY.DP1.10098.001.vst_apparentindividual.2019-11.basic.20250122T230432Z.csv
#     - NEON.D16.ABBY.DP0.10098.001.categoricalCodes.20250122T230432Z.csv
#     - NEON.D16.ABBY.DP1.10098.001.EML.20191105-20191112.20250129T000730Z.xml
#     - NEON.D16.ABBY.DP1.10098.001.vst_mappingandtagging.basic.20250122T230432Z.csv
#     - NEON.D16.ABBY.DP1.10098.001.readme.20250129T000730Z.txt
#     - NEON.D16.ABBY.DP1.10098.001.variables.20250122T230432Z.csv
#     - NEON.D16.ABBY.DP0.10098.001.validation.20250122T230432Z.csv
#   NEON.D03.JERC.DP1.10098.001.2023-11.basic.20250129T000730Z.RELEASE-2025
#     - NEON.D03.JERC.DP1.10098.001.readme.20250129T000730Z.txt
#     - NEON.D03.JERC.DP1.10098.001.variables.20241118T085959Z.csv
#     - NEON.D03.JERC.DP1.10098.001.EML.20231101-20231115.20250129T000730Z.xml
#     - NEON.D03.JERC.DP0.10098.001.categoricalCodes.20241118T085959Z.csv
#     - NEON.D03.JERC.DP1.10098.001.vst_perplotperyear.2023-11.basic.20241118T085959Z.csv
#     - NEON.D03.JERC.DP1.10098.001.vst_apparentindividual.2023-11.basic.20241118T085959Z.csv
#     - NEON.D03.JERC.DP1.10098.001.vst_non-woody.2023-11.basic.20241118T085959Z.csv
#     - NEON.D03.JERC.DP0.10098.001.validation.20241118T085959Z.csv
#     - NEON.D03.JERC.DP1.10098.001.vst_mappingandtagging.basic.20241118T085959Z.csv
#   NEON.D17.TEAK.DP1.10098.001.2022-08.basic.20250129T000730Z.RELEASE-2025
#     - NEON.D17.TEAK.DP0.10098.001.categoricalCodes.20241118T165413Z.csv
#     - NEON.D17.TEAK.DP1.10098.001.vst_shrubgroup.2022-08.basic.20241118T165413Z.csv
#     - NEON.D17.TEAK.DP1.10098.001.readme.20250129T000730Z.txt
#     - NEON.D17.TEAK.DP1.10098.001.vst_apparentindividual.2022-08.basic.20241118T165413Z.csv
#     - NEON.D17.TEAK.DP1.10098.001.variables.20241118T165413Z.csv
#     - NEON.D17.TEAK.DP1.10098.001.vst_mappingandtagging.basic.20241118T165413Z.csv
#     - NEON.D17.TEAK.DP1.10098.001.EML.20220802-20220830.20250129T000730Z.xml
#     - NEON.D17.TEAK.DP0.10098.001.validation.20241118T165413Z.csv
#     - NEON.D17.TEAK.DP1.10098.001.vst_perplotperyear.2022-08.basic.20241118T165413Z.csv
#   NEON.D16.ABBY.DP1.10098.001.2017-03.basic.20250129T000730Z.RELEASE-2025
#     - NEON.D16.ABBY.DP1.10098.001.readme.20250129T000730Z.txt
#     - NEON.D16.ABBY.DP1.10098.001.EML.20170314-20170331.20250129T000730Z.xml
#     - NEON.D16.ABBY.DP0.10098.001.validation.20250122T230318Z.csv
#     - NEON.D16.ABBY.DP1.10098.001.vst_perplotperyear.2017-03.basic.20250122T230318Z.csv
#     - NEON.D16.ABBY.DP0.10098.001.categoricalCodes.20250122T230318Z.csv
#     - NEON.D16.ABBY.DP1.10098.001.vst_mappingandtagging.basic.20250122T230318Z.csv
#     - NEON.D16.ABBY.DP1.10098.001.variables.20250122T230318Z.csv
#     - NEON.D16.ABBY.DP1.10098.001.vst_apparentindividual.2017-03.basic.20250122T230318Z.csv
#   NEON.D13.MOAB.DP1.10098.001.2023-10.basic.20250129T000730Z.RELEASE-2025
#     - NEON.D13.MOAB.DP1.10098.001.vst_mappingandtagging.basic.20241118T012439Z.csv
#     - NEON.D13.MOAB.DP1.10098.001.readme.20250129T000730Z.txt
#     - NEON.D13.MOAB.DP1.10098.001.vst_apparentindividual.2023-10.basic.20241118T012439Z.csv
#     - NEON.D13.MOAB.DP1.10098.001.variables.20241118T012439Z.csv
#     - NEON.D13.MOAB.DP0.10098.001.categoricalCodes.20241118T012439Z.csv
#     - NEON.D13.MOAB.DP1.10098.001.vst_perplotperyear.2023-10.basic.20241118T012439Z.csv
#     - NEON.D13.MOAB.DP0.10098.001.validation.20241118T012439Z.csv
#     - NEON.D13.MOAB.DP1.10098.001.EML.20231004-20231018.20250129T000730Z.xml
#   NEON.D01.HARV.DP1.10098.001.2019-10.basic.20250129T000730Z.RELEASE-2025
#     - NEON.D01.HARV.DP0.10098.001.categoricalCodes.20241118T170918Z.csv
#     - NEON.D01.HARV.DP1.10098.001.vst_mappingandtagging.basic.20241118T170918Z.csv
#     - NEON.D01.HARV.DP1.10098.001.vst_apparentindividual.2019-10.basic.20241118T170918Z.csv
#     - NEON.D01.HARV.DP1.10098.001.variables.20241118T170918Z.csv
#     - NEON.D01.HARV.DP1.10098.001.EML.20191003-20191014.20250129T000730Z.xml
#     - NEON.D01.HARV.DP1.10098.001.readme.20250129T000730Z.txt
#     - NEON.D01.HARV.DP0.10098.001.validation.20241118T170918Z.csv
#   NEON.D06.KONZ.DP1.10098.001.2019-12.basic.20250129T000730Z.RELEASE-2025
#     - NEON.D06.KONZ.DP0.10098.001.categoricalCodes.20241118T105248Z.csv
#     - NEON.D06.KONZ.DP1.10098.001.EML.20191204-20191231.20250129T000730Z.xml
#     - NEON.D06.KONZ.DP1.10098.001.vst_perplotperyear.2019-12.basic.20241118T105248Z.csv
#     - NEON.D06.KONZ.DP1.10098.001.vst_apparentindividual.2019-12.basic.20241118T105248Z.csv
#     - NEON.D06.KONZ.DP0.10098.001.validation.20241118T105248Z.csv
#     - NEON.D06.KONZ.DP1.10098.001.variables.20241118T105248Z.csv
#     - NEON.D06.KONZ.DP1.10098.001.readme.20250129T000730Z.txt
#     - NEON.D06.KONZ.DP1.10098.001.vst_mappingandtagging.basic.20241118T105248Z.csv
#   NEON.D13.NIWO.DP1.10098.001.2023-10.basic.20250129T000730Z.RELEASE-2025
#     - NEON.D13.NIWO.DP1.10098.001.vst_mappingandtagging.basic.20241118T182119Z.csv
#     - NEON.D13.NIWO.DP1.10098.001.vst_apparentindividual.2023-10.basic.20241118T182119Z.csv
#     - NEON.D13.NIWO.DP1.10098.001.readme.20250129T000730Z.txt
#     - NEON.D13.NIWO.DP0.10098.001.categoricalCodes.20241118T182119Z.csv
#     - NEON.D13.NIWO.DP1.10098.001.variables.20241118T182119Z.csv
#     - NEON.D13.NIWO.DP1.10098.001.EML.20231002-20231024.20250129T000730Z.xml
#     - NEON.D13.NIWO.DP1.10098.001.vst_perplotperyear.2023-10.basic.20241118T182119Z.csv
#     - NEON.D13.NIWO.DP0.10098.001.validation.20241118T182119Z.csv
#   NEON.D06.UKFS.DP1.10098.001.2022-01.basic.20250129T000730Z.RELEASE-2025
#     - NEON.D06.UKFS.DP0.10098.001.validation.20241118T152209Z.csv
#     - NEON.D06.UKFS.DP1.10098.001.variables.20241118T152209Z.csv
#     - NEON.D06.UKFS.DP1.10098.001.EML.20220119-20220119.20250129T000730Z.xml
#     - NEON.D06.UKFS.DP1.10098.001.vst_apparentindividual.2022-01.basic.20241118T152209Z.csv
#     - NEON.D06.UKFS.DP0.10098.001.categoricalCodes.20241118T152209Z.csv
#     - NEON.D06.UKFS.DP1.10098.001.readme.20250129T000730Z.txt
#     - NEON.D06.UKFS.DP1.10098.001.vst_perplotperyear.2022-01.basic.20241118T152209Z.csv
#     - NEON.D06.UKFS.DP1.10098.001.vst_mappingandtagging.basic.20241118T152209Z.csv
#   NEON.D02.BLAN.DP1.10098.001.2023-09.basic.20250129T000730Z.RELEASE-2025
#     - NEON.D02.BLAN.DP1.10098.001.readme.20250129T000730Z.txt
#     - NEON.D02.BLAN.DP1.10098.001.EML.20230906-20230920.20250129T000730Z.xml
#     - NEON.D02.BLAN.DP1.10098.001.vst_apparentindividual.2023-09.basic.20241118T060240Z.csv
#     - NEON.D02.BLAN.DP1.10098.001.variables.20241118T060240Z.csv
#     - NEON.D02.BLAN.DP1.10098.001.vst_shrubgroup.2023-09.basic.20241118T060240Z.csv
#     - NEON.D02.BLAN.DP0.10098.001.categoricalCodes.20241118T060240Z.csv
#     - NEON.D02.BLAN.DP1.10098.001.vst_perplotperyear.2023-09.basic.20241118T060240Z.csv
#     - NEON.D02.BLAN.DP0.10098.001.validation.20241118T060240Z.csv
#     - NEON.D02.BLAN.DP1.10098.001.vst_mappingandtagging.basic.20241118T060240Z.csv
#   NEON.D05.TREE.DP1.10098.001.2021-10.basic.20250129T000730Z.RELEASE-2025
#     - NEON.D05.TREE.DP1.10098.001.variables.20241118T171706Z.csv
#     - NEON.D05.TREE.DP0.10098.001.categoricalCodes.20241118T171706Z.csv
#     - NEON.D05.TREE.DP1.10098.001.readme.20250129T000730Z.txt
#     - NEON.D05.TREE.DP1.10098.001.EML.20211001-20211006.20250129T000730Z.xml
#     - NEON.D05.TREE.DP1.10098.001.vst_apparentindividual.2021-10.basic.20241118T171706Z.csv
#     - NEON.D05.TREE.DP0.10098.001.validation.20241118T171706Z.csv
#     - NEON.D05.TREE.DP1.10098.001.vst_mappingandtagging.basic.20241118T171706Z.csv
#     - NEON.D05.TREE.DP1.10098.001.vst_perplotperyear.2021-10.basic.20241118T171706Z.csv
#   NEON.D05.STEI.DP1.10098.001.2021-08.basic.20250129T000730Z.RELEASE-2025
#     - NEON.D05.STEI.DP1.10098.001.vst_apparentindividual.2021-08.basic.20241118T113224Z.csv
#     - NEON.D05.STEI.DP1.10098.001.readme.20250129T000730Z.txt
#     - NEON.D05.STEI.DP1.10098.001.EML.20210830-20210830.20250129T000730Z.xml
#     - NEON.D05.STEI.DP1.10098.001.variables.20241118T113224Z.csv
#     - NEON.D05.STEI.DP0.10098.001.categoricalCodes.20241118T113224Z.csv
#     - NEON.D05.STEI.DP0.10098.001.validation.20241118T113224Z.csv
#     - NEON.D05.STEI.DP1.10098.001.vst_perplotperyear.2021-08.basic.20241118T113224Z.csv
#     - NEON.D05.STEI.DP1.10098.001.vst_mappingandtagging.basic.20241118T113224Z.csv
#   NEON.D16.WREF.DP1.10098.001.2021-10.basic.20250129T000730Z.RELEASE-2025
#     - NEON.D16.WREF.DP0.10098.001.validation.20250122T232153Z.csv
#     - NEON.D16.WREF.DP0.10098.001.categoricalCodes.20250122T232153Z.csv
#     - NEON.D16.WREF.DP1.10098.001.EML.20211001-20211027.20250129T000730Z.xml
#     - NEON.D16.WREF.DP1.10098.001.vst_mappingandtagging.basic.20250122T232153Z.csv
#     - NEON.D16.WREF.DP1.10098.001.vst_perplotperyear.2021-10.basic.20250122T232153Z.csv
#     - NEON.D16.WREF.DP1.10098.001.readme.20250129T000730Z.txt
#     - NEON.D16.WREF.DP1.10098.001.variables.20250122T232153Z.csv
#     - NEON.D16.WREF.DP1.10098.001.vst_apparentindividual.2021-10.basic.20250122T232153Z.csv
#   NEON.D08.LENO.DP1.10098.001.2023-11.basic.20250129T000730Z.RELEASE-2025
#     - NEON.D08.LENO.DP1.10098.001.EML.20231102-20231102.20250129T000730Z.xml
#     - NEON.D08.LENO.DP1.10098.001.readme.20250129T000730Z.txt
#     - NEON.D08.LENO.DP0.10098.001.categoricalCodes.20241118T180243Z.csv
#     - NEON.D08.LENO.DP1.10098.001.vst_perplotperyear.2023-11.basic.20241118T180243Z.csv
#     - NEON.D08.LENO.DP1.10098.001.vst_apparentindividual.2023-11.basic.20241118T180243Z.csv
#     - NEON.D08.LENO.DP0.10098.001.validation.20241118T180243Z.csv
#     - NEON.D08.LENO.DP1.10098.001.variables.20241118T180243Z.csv
#     - NEON.D08.LENO.DP1.10098.001.vst_mappingandtagging.basic.20241118T180243Z.csv
#   NEON.D02.SCBI.DP1.10098.001.2019-10.basic.20250129T000730Z.RELEASE-2025
#     - NEON.D02.SCBI.DP1.10098.001.EML.20191003-20191024.20250129T000730Z.xml
#     - NEON.D02.SCBI.DP0.10098.001.categoricalCodes.20241118T012357Z.csv
#     - NEON.D02.SCBI.DP1.10098.001.vst_apparentindividual.2019-10.basic.20241118T012357Z.csv
#     - NEON.D02.SCBI.DP1.10098.001.readme.20250129T000730Z.txt
#     - NEON.D02.SCBI.DP0.10098.001.validation.20241118T012357Z.csv
#     - NEON.D02.SCBI.DP1.10098.001.variables.20241118T012357Z.csv
#     - NEON.D02.SCBI.DP1.10098.001.vst_mappingandtagging.basic.20241118T012357Z.csv
#     - NEON.D02.SCBI.DP1.10098.001.vst_perplotperyear.2019-10.basic.20241118T012357Z.csv
#   NEON.D07.ORNL.DP1.10098.001.2021-12.basic.20250129T000730Z.RELEASE-2025
#     - NEON.D07.ORNL.DP0.10098.001.categoricalCodes.20241118T065334Z.csv
#     - NEON.D07.ORNL.DP0.10098.001.validation.20241118T065334Z.csv
#     - NEON.D07.ORNL.DP1.10098.001.readme.20250129T000730Z.txt
#     - NEON.D07.ORNL.DP1.10098.001.variables.20241118T065334Z.csv
#     - NEON.D07.ORNL.DP1.10098.001.vst_apparentindividual.2021-12.basic.20241118T065334Z.csv
#     - NEON.D07.ORNL.DP1.10098.001.vst_mappingandtagging.basic.20241118T065334Z.csv
#     - NEON.D07.ORNL.DP1.10098.001.vst_perplotperyear.2021-12.basic.20241118T065334Z.csv
#     - NEON.D07.ORNL.DP1.10098.001.EML.20211201-20211201.20250129T000730Z.xml
#   NEON.D01.HARV.DP1.10098.001.2021-11.basic.20250129T000730Z.RELEASE-2025
#     - NEON.D01.HARV.DP0.10098.001.categoricalCodes.20241118T051721Z.csv
#     - NEON.D01.HARV.DP1.10098.001.variables.20241118T051721Z.csv
#     - NEON.D01.HARV.DP1.10098.001.vst_mappingandtagging.basic.20241118T051721Z.csv
#     - NEON.D01.HARV.DP1.10098.001.EML.20211108-20211108.20250129T000730Z.xml
#     - NEON.D01.HARV.DP1.10098.001.vst_apparentindividual.2021-11.basic.20241118T051721Z.csv
#     - NEON.D01.HARV.DP1.10098.001.readme.20250129T000730Z.txt
#     - NEON.D01.HARV.DP0.10098.001.validation.20241118T051721Z.csv
#   NEON.D14.JORN.DP1.10098.001.2018-10.basic.20250129T000730Z.RELEASE-2025
#     - NEON.D14.JORN.DP1.10098.001.vst_mappingandtagging.basic.20241118T094149Z.csv
#     - NEON.D14.JORN.DP1.10098.001.variables.20241118T094149Z.csv
#     - NEON.D14.JORN.DP1.10098.001.vst_shrubgroup.2018-10.basic.20241118T094149Z.csv
#     - NEON.D14.JORN.DP1.10098.001.vst_perplotperyear.2018-10.basic.20241118T094149Z.csv
#     - NEON.D14.JORN.DP1.10098.001.vst_apparentindividual.2018-10.basic.20241118T094149Z.csv
#     - NEON.D14.JORN.DP1.10098.001.vst_non-woody.2018-10.basic.20241118T094149Z.csv
#     - NEON.D14.JORN.DP1.10098.001.readme.20250129T000730Z.txt
#     - NEON.D14.JORN.DP1.10098.001.EML.20181030-20181031.20250129T000730Z.xml
#     - NEON.D14.JORN.DP0.10098.001.validation.20241118T094149Z.csv
#     - NEON.D14.JORN.DP0.10098.001.categoricalCodes.20241118T094149Z.csv
#   NEON.D02.SERC.DP1.10098.001.2022-10.basic.20250129T000730Z.RELEASE-2025
#     - NEON.D02.SERC.DP1.10098.001.vst_mappingandtagging.basic.20241118T180814Z.csv
#     - NEON.D02.SERC.DP1.10098.001.vst_perplotperyear.2022-10.basic.20241118T180814Z.csv
#     - NEON.D02.SERC.DP0.10098.001.categoricalCodes.20241118T180814Z.csv
#     - NEON.D02.SERC.DP1.10098.001.EML.20221018-20221031.20250129T000730Z.xml
#     - NEON.D02.SERC.DP1.10098.001.variables.20241118T180814Z.csv
#     - NEON.D02.SERC.DP1.10098.001.vst_apparentindividual.2022-10.basic.20241118T180814Z.csv
#     - NEON.D02.SERC.DP1.10098.001.readme.20250129T000730Z.txt
#     - NEON.D02.SERC.DP0.10098.001.validation.20241118T180814Z.csv
#   NEON.D03.OSBS.DP1.10098.001.2019-12.basic.20250129T000730Z.RELEASE-2025
#     - NEON.D03.OSBS.DP0.10098.001.categoricalCodes.20241118T060428Z.csv
#     - NEON.D03.OSBS.DP1.10098.001.EML.20191218-20191218.20250129T000730Z.xml
#     - NEON.D03.OSBS.DP0.10098.001.validation.20241118T060428Z.csv
#     - NEON.D03.OSBS.DP1.10098.001.readme.20250129T000730Z.txt
#     - NEON.D03.OSBS.DP1.10098.001.vst_apparentindividual.2019-12.basic.20241118T060428Z.csv
#     - NEON.D03.OSBS.DP1.10098.001.vst_perplotperyear.2019-12.basic.20241118T060428Z.csv
#     - NEON.D03.OSBS.DP1.10098.001.vst_mappingandtagging.basic.20241118T060428Z.csv
#     - NEON.D03.OSBS.DP1.10098.001.variables.20241118T060428Z.csv
#   NEON.D19.HEAL.DP1.10098.001.2021-05.basic.20250129T000730Z.RELEASE-2025
#     - NEON.D19.HEAL.DP0.10098.001.categoricalCodes.20241118T150702Z.csv
#     - NEON.D19.HEAL.DP1.10098.001.EML.20210524-20210528.20250129T000730Z.xml
#     - NEON.D19.HEAL.DP1.10098.001.readme.20250129T000730Z.txt
#     - NEON.D19.HEAL.DP1.10098.001.vst_perplotperyear.2021-05.basic.20241118T150702Z.csv
#     - NEON.D19.HEAL.DP1.10098.001.vst_mappingandtagging.basic.20241118T150702Z.csv
#     - NEON.D19.HEAL.DP0.10098.001.validation.20241118T150702Z.csv
#     - NEON.D19.HEAL.DP1.10098.001.variables.20241118T150702Z.csv
#   NEON.D05.TREE.DP1.10098.001.2019-11.basic.20250129T000730Z.RELEASE-2025
#     - NEON.D05.TREE.DP1.10098.001.readme.20250129T000730Z.txt
#     - NEON.D05.TREE.DP1.10098.001.vst_mappingandtagging.basic.20241118T083831Z.csv
#     - NEON.D05.TREE.DP1.10098.001.variables.20241118T083831Z.csv
#     - NEON.D05.TREE.DP1.10098.001.vst_perplotperyear.2019-11.basic.20241118T083831Z.csv
#     - NEON.D05.TREE.DP0.10098.001.categoricalCodes.20241118T083831Z.csv
#     - NEON.D05.TREE.DP1.10098.001.EML.20191104-20191105.20250129T000730Z.xml
#     - NEON.D05.TREE.DP1.10098.001.vst_apparentindividual.2019-11.basic.20241118T083831Z.csv
#     - NEON.D05.TREE.DP0.10098.001.validation.20241118T083831Z.csv
#   NEON.D17.TEAK.DP1.10098.001.2022-07.basic.20250129T000730Z.RELEASE-2025
#     - NEON.D17.TEAK.DP1.10098.001.vst_mappingandtagging.basic.20241118T110301Z.csv
#     - NEON.D17.TEAK.DP1.10098.001.readme.20250129T000730Z.txt
#     - NEON.D17.TEAK.DP1.10098.001.EML.20220706-20220721.20250129T000730Z.xml
#     - NEON.D17.TEAK.DP0.10098.001.validation.20241118T110301Z.csv
#     - NEON.D17.TEAK.DP1.10098.001.vst_perplotperyear.2022-07.basic.20241118T110301Z.csv
#     - NEON.D17.TEAK.DP0.10098.001.categoricalCodes.20241118T110301Z.csv
#     - NEON.D17.TEAK.DP1.10098.001.vst_apparentindividual.2022-07.basic.20241118T110301Z.csv
#     - NEON.D17.TEAK.DP1.10098.001.vst_shrubgroup.2022-07.basic.20241118T110301Z.csv
#     - NEON.D17.TEAK.DP1.10098.001.variables.20241118T110301Z.csv
#   NEON.D10.RMNP.DP1.10098.001.2018-09.basic.20250129T000730Z.RELEASE-2025
#     - NEON.D10.RMNP.DP1.10098.001.variables.20241118T043340Z.csv
#     - NEON.D10.RMNP.DP1.10098.001.vst_perplotperyear.2018-09.basic.20241118T043340Z.csv
#     - NEON.D10.RMNP.DP1.10098.001.EML.20180904-20180927.20250129T000730Z.xml
#     - NEON.D10.RMNP.DP1.10098.001.vst_mappingandtagging.basic.20241118T043340Z.csv
#     - NEON.D10.RMNP.DP1.10098.001.readme.20250129T000730Z.txt
#     - NEON.D10.RMNP.DP1.10098.001.vst_apparentindividual.2018-09.basic.20241118T043340Z.csv
#     - NEON.D10.RMNP.DP0.10098.001.validation.20241118T043340Z.csv
#     - NEON.D10.RMNP.DP0.10098.001.categoricalCodes.20241118T043340Z.csv
#   NEON.D03.JERC.DP1.10098.001.2017-06.basic.20250129T000730Z.RELEASE-2025
#     - NEON.D03.JERC.DP0.10098.001.validation.20241118T135038Z.csv
#     - NEON.D03.JERC.DP0.10098.001.categoricalCodes.20241118T135038Z.csv
#     - NEON.D03.JERC.DP1.10098.001.vst_non-woody.2017-06.basic.20241118T135038Z.csv
#     - NEON.D03.JERC.DP1.10098.001.vst_mappingandtagging.basic.20241118T135038Z.csv
#     - NEON.D03.JERC.DP1.10098.001.EML.20170619-20170628.20250129T000730Z.xml
#     - NEON.D03.JERC.DP1.10098.001.variables.20241118T135038Z.csv
#     - NEON.D03.JERC.DP1.10098.001.readme.20250129T000730Z.txt
#   NEON.D03.DSNY.DP1.10098.001.2022-08.basic.20250129T000730Z.RELEASE-2025
#     - NEON.D03.DSNY.DP1.10098.001.vst_mappingandtagging.basic.20241118T035904Z.csv
#     - NEON.D03.DSNY.DP1.10098.001.readme.20250129T000730Z.txt
#     - NEON.D03.DSNY.DP1.10098.001.variables.20241118T035904Z.csv
#     - NEON.D03.DSNY.DP1.10098.001.vst_perplotperyear.2022-08.basic.20241118T035904Z.csv
#     - NEON.D03.DSNY.DP1.10098.001.vst_shrubgroup.2022-08.basic.20241118T035904Z.csv
#     - NEON.D03.DSNY.DP0.10098.001.validation.20241118T035904Z.csv
#     - NEON.D03.DSNY.DP1.10098.001.vst_non-woody.2022-08.basic.20241118T035904Z.csv
#     - NEON.D03.DSNY.DP1.10098.001.EML.20220801-20220810.20250129T000730Z.xml
#     - NEON.D03.DSNY.DP1.10098.001.vst_apparentindividual.2022-08.basic.20241118T035904Z.csv
#     - NEON.D03.DSNY.DP0.10098.001.categoricalCodes.20241118T035904Z.csv
#   NEON.D07.GRSM.DP1.10098.001.2020-01.basic.20250129T000730Z.RELEASE-2025
#     - NEON.D07.GRSM.DP1.10098.001.EML.20200106-20200122.20250129T000730Z.xml
#     - NEON.D07.GRSM.DP1.10098.001.vst_mappingandtagging.basic.20241118T022711Z.csv
#     - NEON.D07.GRSM.DP1.10098.001.vst_apparentindividual.2020-01.basic.20241118T022711Z.csv
#     - NEON.D07.GRSM.DP1.10098.001.vst_perplotperyear.2020-01.basic.20241118T022711Z.csv
#     - NEON.D07.GRSM.DP0.10098.001.validation.20241118T022711Z.csv
#     - NEON.D07.GRSM.DP1.10098.001.variables.20241118T022711Z.csv
#     - NEON.D07.GRSM.DP1.10098.001.readme.20250129T000730Z.txt
#     - NEON.D07.GRSM.DP0.10098.001.categoricalCodes.20241118T022711Z.csv
#   NEON.D05.STEI.DP1.10098.001.2019-09.basic.20250129T000730Z.RELEASE-2025
#     - NEON.D05.STEI.DP0.10098.001.validation.20241118T170722Z.csv
#     - NEON.D05.STEI.DP1.10098.001.vst_non-woody.2019-09.basic.20241118T170722Z.csv
#     - NEON.D05.STEI.DP1.10098.001.vst_apparentindividual.2019-09.basic.20241118T170722Z.csv
#     - NEON.D05.STEI.DP1.10098.001.readme.20250129T000730Z.txt
#     - NEON.D05.STEI.DP1.10098.001.vst_perplotperyear.2019-09.basic.20241118T170722Z.csv
#     - NEON.D05.STEI.DP0.10098.001.categoricalCodes.20241118T170722Z.csv
#     - NEON.D05.STEI.DP1.10098.001.variables.20241118T170722Z.csv
#     - NEON.D05.STEI.DP1.10098.001.vst_mappingandtagging.basic.20241118T170722Z.csv
#     - NEON.D05.STEI.DP1.10098.001.EML.20190903-20190930.20250129T000730Z.xml
#   NEON.D16.WREF.DP1.10098.001.2019-11.basic.20250129T000730Z.RELEASE-2025
#     - NEON.D16.WREF.DP1.10098.001.vst_mappingandtagging.basic.20250122T230226Z.csv
#     - NEON.D16.WREF.DP1.10098.001.EML.20191112-20191127.20250129T000730Z.xml
#     - NEON.D16.WREF.DP1.10098.001.readme.20250129T000730Z.txt
#     - NEON.D16.WREF.DP0.10098.001.categoricalCodes.20250122T230226Z.csv
#     - NEON.D16.WREF.DP1.10098.001.variables.20250122T230226Z.csv
#     - NEON.D16.WREF.DP0.10098.001.validation.20250122T230226Z.csv
#     - NEON.D16.WREF.DP1.10098.001.vst_perplotperyear.2019-11.basic.20250122T230226Z.csv
#     - NEON.D16.WREF.DP1.10098.001.vst_apparentindividual.2019-11.basic.20250122T230226Z.csv
#   NEON.D07.MLBS.DP1.10098.001.2019-10.basic.20250129T000730Z.RELEASE-2025
#     - NEON.D07.MLBS.DP0.10098.001.categoricalCodes.20241118T111741Z.csv
#     - NEON.D07.MLBS.DP1.10098.001.vst_apparentindividual.2019-10.basic.20241118T111741Z.csv
#     - NEON.D07.MLBS.DP1.10098.001.EML.20191007-20191030.20250129T000730Z.xml
#     - NEON.D07.MLBS.DP1.10098.001.readme.20250129T000730Z.txt
#     - NEON.D07.MLBS.DP1.10098.001.vst_mappingandtagging.basic.20241118T111741Z.csv
#     - NEON.D07.MLBS.DP0.10098.001.validation.20241118T111741Z.csv
#     - NEON.D07.MLBS.DP1.10098.001.vst_perplotperyear.2019-10.basic.20241118T111741Z.csv
#     - NEON.D07.MLBS.DP1.10098.001.variables.20241118T111741Z.csv
#   NEON.D10.RMNP.DP1.10098.001.2017-10.basic.20250129T000730Z.RELEASE-2025
#     - NEON.D10.RMNP.DP1.10098.001.variables.20241118T011205Z.csv
#     - NEON.D10.RMNP.DP0.10098.001.categoricalCodes.20241118T011205Z.csv
#     - NEON.D10.RMNP.DP1.10098.001.readme.20250129T000730Z.txt
#     - NEON.D10.RMNP.DP1.10098.001.vst_apparentindividual.2017-10.basic.20241118T011205Z.csv
#     - NEON.D10.RMNP.DP0.10098.001.validation.20241118T011205Z.csv
#     - NEON.D10.RMNP.DP1.10098.001.EML.20171003-20171010.20250129T000730Z.xml
#     - NEON.D10.RMNP.DP1.10098.001.vst_perplotperyear.2017-10.basic.20241118T011205Z.csv
#     - NEON.D10.RMNP.DP1.10098.001.vst_mappingandtagging.basic.20241118T011205Z.csv
#   NEON.D05.STEI.DP1.10098.001.2022-08.basic.20250129T000730Z.RELEASE-2025
#     - NEON.D05.STEI.DP1.10098.001.variables.20241118T005328Z.csv
#     - NEON.D05.STEI.DP1.10098.001.vst_mappingandtagging.basic.20241118T005328Z.csv
#     - NEON.D05.STEI.DP0.10098.001.categoricalCodes.20241118T005328Z.csv
#     - NEON.D05.STEI.DP0.10098.001.validation.20241118T005328Z.csv
#     - NEON.D05.STEI.DP1.10098.001.readme.20250129T000730Z.txt
#     - NEON.D05.STEI.DP1.10098.001.EML.20220830-20220831.20250129T000730Z.xml
#     - NEON.D05.STEI.DP1.10098.001.vst_perplotperyear.2022-08.basic.20241118T005328Z.csv
#     - NEON.D05.STEI.DP1.10098.001.vst_apparentindividual.2022-08.basic.20241118T005328Z.csv
# ...
#     - NEON.D02.BLAN.DP1.10098.001.vst_perplotperyear.2023-12.basic.20241118T163441Z.csv
#     - NEON.D02.BLAN.DP0.10098.001.validation.20241118T163441Z.csv
#     - NEON.D02.BLAN.DP1.10098.001.readme.20250129T000730Z.txt
#     - NEON.D02.BLAN.DP1.10098.001.variables.20241118T163441Z.csv
#     - NEON.D02.BLAN.DP1.10098.001.vst_mappingandtagging.basic.20241118T163441Z.csv
#   NEON.D12.YELL.DP1.10098.001.2021-10.basic.20250129T000730Z.RELEASE-2025
#     - NEON.D12.YELL.DP1.10098.001.EML.20211004-20211007.20250129T000730Z.xml
#     - NEON.D12.YELL.DP1.10098.001.variables.20241118T024742Z.csv
#     - NEON.D12.YELL.DP1.10098.001.vst_apparentindividual.2021-10.basic.20241118T024742Z.csv
#     - NEON.D12.YELL.DP0.10098.001.categoricalCodes.20241118T024742Z.csv
#     - NEON.D12.YELL.DP1.10098.001.readme.20250129T000730Z.txt
#     - NEON.D12.YELL.DP0.10098.001.validation.20241118T024742Z.csv
#     - NEON.D12.YELL.DP1.10098.001.vst_mappingandtagging.basic.20241118T024742Z.csv
#   NEON.D06.UKFS.DP1.10098.001.2018-10.basic.20250129T000730Z.RELEASE-2025
#     - NEON.D06.UKFS.DP0.10098.001.validation.20241118T021126Z.csv
#     - NEON.D06.UKFS.DP1.10098.001.vst_apparentindividual.2018-10.basic.20241118T021126Z.csv
#     - NEON.D06.UKFS.DP0.10098.001.categoricalCodes.20241118T021126Z.csv
#     - NEON.D06.UKFS.DP1.10098.001.vst_perplotperyear.2018-10.basic.20241118T021126Z.csv
#     - NEON.D06.UKFS.DP1.10098.001.variables.20241118T021126Z.csv
#     - NEON.D06.UKFS.DP1.10098.001.readme.20250129T000730Z.txt
#     - NEON.D06.UKFS.DP1.10098.001.vst_mappingandtagging.basic.20241118T021126Z.csv
#     - NEON.D06.UKFS.DP1.10098.001.EML.20181002-20181025.20250129T000730Z.xml
#   NEON.D05.UNDE.DP1.10098.001.2020-09.basic.20250129T000730Z.RELEASE-2025
#     - NEON.D05.UNDE.DP0.10098.001.categoricalCodes.20241118T204603Z.csv
#     - NEON.D05.UNDE.DP0.10098.001.validation.20241118T204603Z.csv
#     - NEON.D05.UNDE.DP1.10098.001.vst_apparentindividual.2020-09.basic.20241118T204603Z.csv
#     - NEON.D05.UNDE.DP1.10098.001.vst_mappingandtagging.basic.20241118T204603Z.csv
#     - NEON.D05.UNDE.DP1.10098.001.vst_perplotperyear.2020-09.basic.20241118T204603Z.csv
#     - NEON.D05.UNDE.DP1.10098.001.readme.20250129T000730Z.txt
#     - NEON.D05.UNDE.DP1.10098.001.EML.20200913-20200929.20250129T000730Z.xml
#     - NEON.D05.UNDE.DP1.10098.001.variables.20241118T204603Z.csv
#   NEON.D15.ONAQ.DP1.10098.001.2022-10.basic.20250129T000730Z.RELEASE-2025
#     - NEON.D15.ONAQ.DP1.10098.001.vst_mappingandtagging.basic.20241118T150233Z.csv
#     - NEON.D15.ONAQ.DP0.10098.001.categoricalCodes.20241118T150233Z.csv
#     - NEON.D15.ONAQ.DP1.10098.001.EML.20221006-20221031.20250129T000730Z.xml
#     - NEON.D15.ONAQ.DP1.10098.001.readme.20250129T000730Z.txt
#     - NEON.D15.ONAQ.DP1.10098.001.vst_apparentindividual.2022-10.basic.20241118T150233Z.csv
#     - NEON.D15.ONAQ.DP1.10098.001.variables.20241118T150233Z.csv
#     - NEON.D15.ONAQ.DP0.10098.001.validation.20241118T150233Z.csv
#     - NEON.D15.ONAQ.DP1.10098.001.vst_perplotperyear.2022-10.basic.20241118T150233Z.csv
#   NEON.D06.KONZ.DP1.10098.001.2018-11.basic.20250129T000730Z.RELEASE-2025
#     - NEON.D06.KONZ.DP0.10098.001.validation.20241118T035325Z.csv
#     - NEON.D06.KONZ.DP1.10098.001.readme.20250129T000730Z.txt
#     - NEON.D06.KONZ.DP1.10098.001.vst_mappingandtagging.basic.20241118T035325Z.csv
#     - NEON.D06.KONZ.DP1.10098.001.vst_perplotperyear.2018-11.basic.20241118T035325Z.csv
#     - NEON.D06.KONZ.DP1.10098.001.vst_apparentindividual.2018-11.basic.20241118T035325Z.csv
#     - NEON.D06.KONZ.DP1.10098.001.variables.20241118T035325Z.csv
#     - NEON.D06.KONZ.DP1.10098.001.EML.20181108-20181116.20250129T000730Z.xml
#     - NEON.D06.KONZ.DP0.10098.001.categoricalCodes.20241118T035325Z.csv
#   NEON.D07.GRSM.DP1.10098.001.2017-11.basic.20250129T000730Z.RELEASE-2025
#     - NEON.D07.GRSM.DP1.10098.001.readme.20250129T000730Z.txt
#     - NEON.D07.GRSM.DP1.10098.001.vst_mappingandtagging.basic.20241118T112613Z.csv
#     - NEON.D07.GRSM.DP1.10098.001.EML.20171101-20171130.20250129T000730Z.xml
#     - NEON.D07.GRSM.DP0.10098.001.validation.20241118T112613Z.csv
#     - NEON.D07.GRSM.DP1.10098.001.vst_perplotperyear.2017-11.basic.20241118T112613Z.csv
#     - NEON.D07.GRSM.DP1.10098.001.vst_apparentindividual.2017-11.basic.20241118T112613Z.csv
#     - NEON.D07.GRSM.DP1.10098.001.variables.20241118T112613Z.csv
#     - NEON.D07.GRSM.DP0.10098.001.categoricalCodes.20241118T112613Z.csv
#   NEON.D04.GUAN.DP1.10098.001.2023-12.basic.20250129T000730Z.RELEASE-2025
#     - NEON.D04.GUAN.DP1.10098.001.readme.20250129T000730Z.txt
#     - NEON.D04.GUAN.DP1.10098.001.vst_non-woody.2023-12.basic.20241118T162535Z.csv
#     - NEON.D04.GUAN.DP1.10098.001.vst_shrubgroup.2023-12.basic.20241118T162535Z.csv
#     - NEON.D04.GUAN.DP1.10098.001.vst_perplotperyear.2023-12.basic.20241118T162535Z.csv
#     - NEON.D04.GUAN.DP0.10098.001.categoricalCodes.20241118T162535Z.csv
#     - NEON.D04.GUAN.DP1.10098.001.vst_apparentindividual.2023-12.basic.20241118T162535Z.csv
#     - NEON.D04.GUAN.DP1.10098.001.EML.20231204-20231227.20250129T000730Z.xml
#     - NEON.D04.GUAN.DP0.10098.001.validation.20241118T162535Z.csv
#     - NEON.D04.GUAN.DP1.10098.001.vst_mappingandtagging.basic.20241118T162535Z.csv
#     - NEON.D04.GUAN.DP1.10098.001.variables.20241118T162535Z.csv
#   NEON.D08.DELA.DP1.10098.001.2022-01.basic.20250129T000730Z.RELEASE-2025
#     - NEON.D08.DELA.DP1.10098.001.EML.20220119-20220128.20250129T000730Z.xml
#     - NEON.D08.DELA.DP1.10098.001.vst_perplotperyear.2022-01.basic.20241118T055607Z.csv
#     - NEON.D08.DELA.DP1.10098.001.vst_apparentindividual.2022-01.basic.20241118T055607Z.csv
#     - NEON.D08.DELA.DP1.10098.001.variables.20241118T055607Z.csv
#     - NEON.D08.DELA.DP1.10098.001.readme.20250129T000730Z.txt
#     - NEON.D08.DELA.DP0.10098.001.categoricalCodes.20241118T055607Z.csv
#     - NEON.D08.DELA.DP0.10098.001.validation.20241118T055607Z.csv
#     - NEON.D08.DELA.DP1.10098.001.vst_mappingandtagging.basic.20241118T055607Z.csv
#   NEON.D03.DSNY.DP1.10098.001.2018-05.basic.20250129T000730Z.RELEASE-2025
#     - NEON.D03.DSNY.DP1.10098.001.EML.20180501-20180503.20250129T000730Z.xml
#     - NEON.D03.DSNY.DP1.10098.001.vst_apparentindividual.2018-05.basic.20241118T130128Z.csv
#     - NEON.D03.DSNY.DP1.10098.001.vst_perplotperyear.2018-05.basic.20241118T130128Z.csv
#     - NEON.D03.DSNY.DP0.10098.001.validation.20241118T130128Z.csv
#     - NEON.D03.DSNY.DP1.10098.001.readme.20250129T000730Z.txt
#     - NEON.D03.DSNY.DP1.10098.001.vst_mappingandtagging.basic.20241118T130128Z.csv
#     - NEON.D03.DSNY.DP0.10098.001.categoricalCodes.20241118T130128Z.csv
#     - NEON.D03.DSNY.DP1.10098.001.variables.20241118T130128Z.csv
#   NEON.D20.PUUM.DP1.10098.001.2018-08.basic.20250129T000730Z.RELEASE-2025
#     - NEON.D20.PUUM.DP1.10098.001.readme.20250129T000730Z.txt
#     - NEON.D20.PUUM.DP1.10098.001.vst_apparentindividual.2018-08.basic.20241118T034339Z.csv
#     - NEON.D20.PUUM.DP1.10098.001.variables.20241118T034339Z.csv
#     - NEON.D20.PUUM.DP1.10098.001.vst_mappingandtagging.basic.20241118T034339Z.csv
#     - NEON.D20.PUUM.DP1.10098.001.vst_non-woody.2018-08.basic.20241118T034339Z.csv
#     - NEON.D20.PUUM.DP1.10098.001.vst_perplotperyear.2018-08.basic.20241118T034339Z.csv
#     - NEON.D20.PUUM.DP0.10098.001.categoricalCodes.20241118T034339Z.csv
#     - NEON.D20.PUUM.DP0.10098.001.validation.20241118T034339Z.csv
#     - NEON.D20.PUUM.DP1.10098.001.EML.20180802-20180806.20250129T000730Z.xml
#   NEON.D15.ONAQ.DP1.10098.001.2017-10.basic.20250129T000730Z.RELEASE-2025
#     - NEON.D15.ONAQ.DP1.10098.001.readme.20250129T000730Z.txt
#     - NEON.D15.ONAQ.DP1.10098.001.vst_non-woody.2017-10.basic.20241118T061606Z.csv
#     - NEON.D15.ONAQ.DP0.10098.001.validation.20241118T061606Z.csv
#     - NEON.D15.ONAQ.DP1.10098.001.vst_apparentindividual.2017-10.basic.20241118T061606Z.csv
#     - NEON.D15.ONAQ.DP0.10098.001.categoricalCodes.20241118T061606Z.csv
#     - NEON.D15.ONAQ.DP1.10098.001.vst_mappingandtagging.basic.20241118T061606Z.csv
#     - NEON.D15.ONAQ.DP1.10098.001.EML.20171003-20171031.20250129T000730Z.xml
#     - NEON.D15.ONAQ.DP1.10098.001.variables.20241118T061606Z.csv
#     - NEON.D15.ONAQ.DP1.10098.001.vst_perplotperyear.2017-10.basic.20241118T061606Z.csv
#   NEON.D20.PUUM.DP1.10098.001.2023-09.basic.20250129T000730Z.RELEASE-2025
#     - NEON.D20.PUUM.DP1.10098.001.EML.20230906-20230928.20250129T000730Z.xml
#     - NEON.D20.PUUM.DP1.10098.001.vst_apparentindividual.2023-09.basic.20241119T222418Z.csv
#     - NEON.D20.PUUM.DP1.10098.001.vst_mappingandtagging.basic.20241119T222418Z.csv
#     - NEON.D20.PUUM.DP1.10098.001.vst_non-woody.2023-09.basic.20241119T222418Z.csv
#     - NEON.D20.PUUM.DP1.10098.001.vst_perplotperyear.2023-09.basic.20241119T222418Z.csv
#     - NEON.D20.PUUM.DP1.10098.001.readme.20250129T000730Z.txt
#     - NEON.D20.PUUM.DP0.10098.001.validation.20241119T222418Z.csv
#     - NEON.D20.PUUM.DP0.10098.001.categoricalCodes.20241119T222418Z.csv
#     - NEON.D20.PUUM.DP1.10098.001.variables.20241119T222418Z.csv
#     - NEON.D20.PUUM.DP1.10098.001.vst_shrubgroup.2023-09.basic.20241119T222418Z.csv
#   NEON.D06.UKFS.DP1.10098.001.2022-09.basic.20250129T000730Z.RELEASE-2025
#     - NEON.D06.UKFS.DP1.10098.001.vst_perplotperyear.2022-09.basic.20241118T162048Z.csv
#     - NEON.D06.UKFS.DP1.10098.001.variables.20241118T162048Z.csv
#     - NEON.D06.UKFS.DP1.10098.001.vst_mappingandtagging.basic.20241118T162048Z.csv
#     - NEON.D06.UKFS.DP0.10098.001.validation.20241118T162048Z.csv
#     - NEON.D06.UKFS.DP1.10098.001.EML.20220930-20220930.20250129T000730Z.xml
#     - NEON.D06.UKFS.DP0.10098.001.categoricalCodes.20241118T162048Z.csv
#     - NEON.D06.UKFS.DP1.10098.001.readme.20250129T000730Z.txt
#   NEON.D07.GRSM.DP1.10098.001.2022-02.basic.20250129T000730Z.RELEASE-2025
#     - NEON.D07.GRSM.DP0.10098.001.categoricalCodes.20241118T013344Z.csv
#     - NEON.D07.GRSM.DP0.10098.001.validation.20241118T013344Z.csv
#     - NEON.D07.GRSM.DP1.10098.001.vst_apparentindividual.2022-02.basic.20241118T013344Z.csv
#     - NEON.D07.GRSM.DP1.10098.001.readme.20250129T000730Z.txt
#     - NEON.D07.GRSM.DP1.10098.001.variables.20241118T013344Z.csv
#     - NEON.D07.GRSM.DP1.10098.001.vst_perplotperyear.2022-02.basic.20241118T013344Z.csv
#     - NEON.D07.GRSM.DP1.10098.001.vst_mappingandtagging.basic.20241118T013344Z.csv
#     - NEON.D07.GRSM.DP1.10098.001.EML.20220210-20220216.20250129T000730Z.xml
#   NEON.D02.SCBI.DP1.10098.001.2023-12.basic.20250129T000730Z.RELEASE-2025
#     - NEON.D02.SCBI.DP1.10098.001.readme.20250129T000730Z.txt
#     - NEON.D02.SCBI.DP1.10098.001.vst_mappingandtagging.basic.20241118T210944Z.csv
#     - NEON.D02.SCBI.DP0.10098.001.categoricalCodes.20241118T210944Z.csv
#     - NEON.D02.SCBI.DP1.10098.001.EML.20231204-20231213.20250129T000730Z.xml
#     - NEON.D02.SCBI.DP0.10098.001.validation.20241118T210944Z.csv
#     - NEON.D02.SCBI.DP1.10098.001.vst_perplotperyear.2023-12.basic.20241118T210944Z.csv
#     - NEON.D02.SCBI.DP1.10098.001.variables.20241118T210944Z.csv
#     - NEON.D02.SCBI.DP1.10098.001.vst_apparentindividual.2023-12.basic.20241118T210944Z.csv
#   NEON.D03.JERC.DP1.10098.001.2022-12.basic.20250129T000730Z.RELEASE-2025
#     - NEON.D03.JERC.DP1.10098.001.EML.20221201-20221207.20250129T000730Z.xml
#     - NEON.D03.JERC.DP1.10098.001.vst_apparentindividual.2022-12.basic.20241118T045458Z.csv
#     - NEON.D03.JERC.DP1.10098.001.readme.20250129T000730Z.txt
#     - NEON.D03.JERC.DP1.10098.001.variables.20241118T045458Z.csv
#     - NEON.D03.JERC.DP0.10098.001.validation.20241118T045458Z.csv
#     - NEON.D03.JERC.DP1.10098.001.vst_perplotperyear.2022-12.basic.20241118T045458Z.csv
#     - NEON.D03.JERC.DP0.10098.001.categoricalCodes.20241118T045458Z.csv
#     - NEON.D03.JERC.DP1.10098.001.vst_mappingandtagging.basic.20241118T045458Z.csv
#   NEON.D01.HARV.DP1.10098.001.2023-12.basic.20250129T000730Z.RELEASE-2025
#     - NEON.D01.HARV.DP1.10098.001.variables.20241118T082545Z.csv
#     - NEON.D01.HARV.DP0.10098.001.categoricalCodes.20241118T082545Z.csv
#     - NEON.D01.HARV.DP0.10098.001.validation.20241118T082545Z.csv
#     - NEON.D01.HARV.DP1.10098.001.vst_mappingandtagging.basic.20241118T082545Z.csv
#     - NEON.D01.HARV.DP1.10098.001.vst_apparentindividual.2023-12.basic.20241118T082545Z.csv
#     - NEON.D01.HARV.DP1.10098.001.readme.20250129T000730Z.txt
#     - NEON.D01.HARV.DP1.10098.001.EML.20231204-20231204.20250129T000730Z.xml
#   NEON.D19.HEAL.DP1.10098.001.2020-09.basic.20250129T000730Z.RELEASE-2025
#     - NEON.D19.HEAL.DP0.10098.001.validation.20241118T214012Z.csv
#     - NEON.D19.HEAL.DP1.10098.001.vst_mappingandtagging.basic.20241118T214012Z.csv
#     - NEON.D19.HEAL.DP1.10098.001.readme.20250129T000730Z.txt
#     - NEON.D19.HEAL.DP1.10098.001.vst_apparentindividual.2020-09.basic.20241118T214012Z.csv
#     - NEON.D19.HEAL.DP1.10098.001.variables.20241118T214012Z.csv
#     - NEON.D19.HEAL.DP1.10098.001.vst_perplotperyear.2020-09.basic.20241118T214012Z.csv
#     - NEON.D19.HEAL.DP0.10098.001.categoricalCodes.20241118T214012Z.csv
#     - NEON.D19.HEAL.DP1.10098.001.EML.20200901-20200921.20250129T000730Z.xml
#   NEON.D17.SOAP.DP1.10098.001.2020-07.basic.20250129T000730Z.RELEASE-2025
#     - NEON.D17.SOAP.DP1.10098.001.readme.20250129T000730Z.txt
#     - NEON.D17.SOAP.DP1.10098.001.vst_perplotperyear.2020-07.basic.20241118T110326Z.csv
#     - NEON.D17.SOAP.DP1.10098.001.vst_mappingandtagging.basic.20241118T110326Z.csv
#     - NEON.D17.SOAP.DP0.10098.001.validation.20241118T110326Z.csv
#     - NEON.D17.SOAP.DP1.10098.001.EML.20200707-20200708.20250129T000730Z.xml
#     - NEON.D17.SOAP.DP0.10098.001.categoricalCodes.20241118T110326Z.csv
#     - NEON.D17.SOAP.DP1.10098.001.variables.20241118T110326Z.csv
#   NEON.D01.BART.DP1.10098.001.2023-10.basic.20250129T000730Z.RELEASE-2025
#     - NEON.D01.BART.DP1.10098.001.variables.20241118T084049Z.csv
#     - NEON.D01.BART.DP1.10098.001.vst_apparentindividual.2023-10.basic.20241118T084049Z.csv
#     - NEON.D01.BART.DP0.10098.001.validation.20241118T084049Z.csv
#     - NEON.D01.BART.DP1.10098.001.readme.20250129T000730Z.txt
#     - NEON.D01.BART.DP0.10098.001.categoricalCodes.20241118T084049Z.csv
#     - NEON.D01.BART.DP1.10098.001.vst_mappingandtagging.basic.20241118T084049Z.csv
#     - NEON.D01.BART.DP1.10098.001.EML.20231018-20231018.20250129T000730Z.xml
#   NEON.D01.BART.DP1.10098.001.2017-08.basic.20250129T000730Z.RELEASE-2025
#     - NEON.D01.BART.DP0.10098.001.categoricalCodes.20241118T015553Z.csv
#     - NEON.D01.BART.DP1.10098.001.vst_mappingandtagging.basic.20241118T015553Z.csv
#     - NEON.D01.BART.DP1.10098.001.readme.20250129T000730Z.txt
#     - NEON.D01.BART.DP1.10098.001.EML.20170828-20170830.20250129T000730Z.xml
#     - NEON.D01.BART.DP1.10098.001.variables.20241118T015553Z.csv
#     - NEON.D01.BART.DP0.10098.001.validation.20241118T015553Z.csv
#     - NEON.D01.BART.DP1.10098.001.vst_apparentindividual.2017-08.basic.20241118T015553Z.csv
#   NEON.D01.HARV.DP1.10098.001.2022-07.basic.20250129T000730Z.RELEASE-2025
#     - NEON.D01.HARV.DP1.10098.001.EML.20220714-20220714.20250129T000730Z.xml
#     - NEON.D01.HARV.DP1.10098.001.readme.20250129T000730Z.txt
#     - NEON.D01.HARV.DP1.10098.001.vst_mappingandtagging.basic.20241118T120808Z.csv
#     - NEON.D01.HARV.DP0.10098.001.validation.20241118T120808Z.csv
#     - NEON.D01.HARV.DP1.10098.001.vst_perplotperyear.2022-07.basic.20241118T120808Z.csv
#     - NEON.D01.HARV.DP1.10098.001.variables.20241118T120808Z.csv
#     - NEON.D01.HARV.DP0.10098.001.categoricalCodes.20241118T120808Z.csv
#
# Toplam CSV: 3690
# Örnek 5: ['BART_2023-10_individuals_with_coords.csv', 'SJER_2019-10_individuals_with_coords.csv', 'SJER_2019-11_individuals_with_coords.csv', 'SJER_2019-12_individuals_with_coords.csv', 'SJER_2022-01_individuals_with_coords.csv']
#
# --- BART_2023-10_individuals_with_coords.csv ---
# Kolonlar: ['individualID', 'scientificName', 'lat', 'lon', 'plotID']
#
# --- SJER_2019-10_individuals_with_coords.csv ---
# Kolonlar: ['individualID', 'scientificName', 'lat', 'lon']
#
# --- SJER_2019-11_individuals_with_coords.csv ---
# Kolonlar: ['individualID', 'scientificName', 'lat', 'lon']
#
# --- SJER_2019-12_individuals_with_coords.csv ---
# Kolonlar: ['individualID', 'scientificName', 'lat', 'lon']
#
# --- SJER_2022-01_individuals_with_coords.csv ---
# Kolonlar: ['individualID', 'scientificName', 'lat', 'lon']

# %%
# ==== Field noktaları (2017–2020) ====
itc_csvs = glob.glob(os.path.join(BASE_NEON, "*_individuals_with_coords.csv"))

gdfs = []
for p in itc_csvs:
    # yıl & site ismini dosya adından çıkar
    m_year = re.search(r"_(\d{4})-", os.path.basename(p))
    year = int(m_year.group(1)) if m_year else None
    if (year is None) or not (2017 <= year <= 2020):
        continue

    df = pd.read_csv(p, low_memory=False)
    # lon/lat için esnek seçim
    cl = {c.lower(): c for c in df.columns}
    lon = cl.get("lon") or cl.get("longitude")
    lat = cl.get("lat") or cl.get("latitude")
    if not lon or not lat:
        continue

    g = gpd.GeoDataFrame(
        df,
        geometry=gpd.points_from_xy(df[lon].astype(float), df[lat].astype(float)),
        crs="EPSG:4326"
    ).to_crs(5070)

    m_site = re.search(r"^([A-Z]{3,4})_", os.path.basename(p))
    g["site_field"] = m_site.group(1) if m_site else None
    g["year_field"] = year

    keep = [c for c in ["individualID","scientificName","year_field","site_field","geometry"] if c in g.columns or c=="geometry"]
    gdfs.append(g[keep])

field_pts = gpd.GeoDataFrame(pd.concat(gdfs, ignore_index=True), crs=5070) if gdfs else gpd.GeoDataFrame(crs=5070)
print("Field noktaları:", len(field_pts))
field_pts.head(3)
# Out:
# Field noktaları: 582
#               individualID            scientificName  year_field site_field  \
# 0  NEON.PLA.D17.SJER.00037  Quercus wislizeni A. DC.        2019       SJER
# 1  NEON.PLA.D17.SJER.00148  Quercus wislizeni A. DC.        2019       SJER
# 2  NEON.PLA.D17.SJER.00149  Quercus wislizeni A. DC.        2019       SJER
#
#                            geometry
# 0  POINT (-2067133.252 1822983.277)
# 1  POINT (-2067147.879 1822638.099)
# 2  POINT (-2067147.693 1822638.997)

# %%
# ==== Poligon okuma & yıl/site çıkarma ====
layers = fiona.listlayers(POLY_GPKG)
pref = ["polygons_with_species", "Tree_to_Species", "all_matches"]
layer = next((L for L in pref if L in layers), layers[0])
print("Seçilen layer:", layer)

polys = gpd.read_file(POLY_GPKG, layer=layer).to_crs(5070)
print("Poligon sayısı (ham):", len(polys))

# Kaynak kolon adayları (xml/rgb/file/name)
cand_keys = [c for c in polys.columns if any(k in c.lower() for k in ["source","xml","rgb","file","name","filename"])]

def extract_year_any(row):
    for c in cand_keys:
        m = re.search(r"(20\d{2})", str(row.get(c)))
        if m: return int(m.group(1))
    return None

def extract_site_any(row):
    for c in cand_keys:
        m = re.search(r"\b([A-Z]{3,4})\b", str(row.get(c)))
        if m: return m.group(1)
    return None

polys["year_ann"] = polys.apply(extract_year_any, axis=1)
polys["site_ann"] = polys.apply(extract_site_any, axis=1)
polys = polys[(polys["year_ann"]>=2017) & (polys["year_ann"]<=2020)]
print("Poligon (2017–2020):", len(polys))
polys.head(3)
# Out:
# Seçilen layer: polygons_with_species
# Poligon sayısı (ham): 221958
# Poligon (2017–2020): 221512
#   source_xml_x                              source_rgb_x label_x  ann_index  \
# 0       10.xml  2018_SJER_3_255000_4107000_image_298.tif    Tree          0
# 1       10.xml  2018_SJER_3_255000_4107000_image_298.tif    Tree          0
# 2       10.xml  2018_SJER_3_255000_4107000_image_298.tif    Tree          0
#
#   source_xml_y                              source_rgb_y label_y  index_right  \
# 0       10.xml  2018_SJER_3_255000_4107000_image_298.tif    Tree         1569
# 1       10.xml  2018_SJER_3_255000_4107000_image_298.tif    Tree         1181
# 2       10.xml  2018_SJER_3_255000_4107000_image_298.tif    Tree         1957
#
#               individualID                  scientificName        lat  \
# 0  NEON.PLA.D17.SJER.04149  Quercus douglasii Hook. & Arn.  37.082927
# 1  NEON.PLA.D17.SJER.04149  Quercus douglasii Hook. & Arn.  37.082927
# 2  NEON.PLA.D17.SJER.04149  Quercus douglasii Hook. & Arn.  37.082927
#
#           lon plotID _coord_src      dist_m match_type  \
# 0 -119.743247   None         LL  810.322945       None
# 1 -119.743247   None         LL  810.322945       None
# 2 -119.743247   None         LL  810.322945       None
#
#                                             geometry  year_ann site_ann
# 0  POLYGON ((-2069836.038 1820410.01, -2069833.61...    2018.0     None
# 1  POLYGON ((-2069836.038 1820410.01, -2069833.61...    2018.0     None
# 2  POLYGON ((-2069836.038 1820410.01, -2069833.61...    2018.0     None

# %%
# ==== Join edilmiş tabloyu yükle & species coalesce ====
JOIN_CSV = f"{ANN_WS}/Tree_to_FieldSpecies_joined_FIXED.csv"

joined = None
if os.path.exists(JOIN_CSV):
    joined = pd.read_csv(JOIN_CSV, low_memory=False)
    print("Yüklendi:", os.path.basename(JOIN_CSV), "| Satır:", len(joined))
    # species benzeri kolonları topla ve ilk dolu olanı 'species' olarak birleştir
    bases = ["scientificName", "taxonID", "species", "species_pred", "sci_name", "speciesName", "taxon"]
    cand_cols = []
    for c in joined.columns:
        lc = c.lower()
        for b in bases:
            if lc == b.lower() or lc.startswith(b.lower()+"_"):
                cand_cols.append(c)
    cand_cols = list(dict.fromkeys(cand_cols))

    joined["species"] = None
    for c in cand_cols:
        joined["species"] = joined["species"].fillna(joined[c])

    joined["species"] = joined["species"].replace(["", "None", "nan"], pd.NA)
    print("Etiketli (species not null):", int(joined["species"].notna().sum()))
else:
    print("Join CSV bulunamadı, bu hücreyi atlıyorum:", JOIN_CSV)
# Out:
# Yüklendi: Tree_to_FieldSpecies_joined_FIXED.csv | Satır: 221958
# Etiketli (species not null): 221958

# %%
# ==== En iyi eşleşme seçimi & SAFE kaydet ====
if joined is not None:
    # match_type & mesafe kolonlarını tekilleştir
    match_candidates = [c for c in joined.columns if c.lower().startswith("match_type")]
    dist_candidates  = [c for c in joined.columns if c.lower().startswith("dist_m")]

    def coalesce_row(row, cols):
        for c in cols:
            v = row.get(c)
            if pd.notna(v):
                return v
        return np.nan

    joined["match_type_c"] = joined.apply(lambda r: coalesce_row(r, match_candidates), axis=1)
    joined["dist_m_c"]     = joined.apply(lambda r: coalesce_row(r, dist_candidates), axis=1)
    joined["match_type_c"] = joined["match_type_c"].fillna("no_hit")

    # yoksa ann_index = index
    if "ann_index" not in joined.columns:
        joined["ann_index"] = joined.index

    rank_map = {"within":0, "nearest_centroid":1, "stem_buffer_intersects":2, "nearest":3, "no_hit":99}
    joined["_rank"] = joined["match_type_c"].map(rank_map).fillna(99).astype(int)
    joined["_dist"] = pd.to_numeric(joined["dist_m_c"], errors="coerce").fillna(1e12)

    best = (
        joined.sort_values(["ann_index","_rank","_dist"])
              .drop_duplicates(subset=["ann_index"], keep="first")
              .copy()
    )

    # güven etiketi
    NEAREST_THRESH_M = 3.0
    def conf(mt, d):
        if mt == "within": return "high"
        if mt in ("nearest_centroid","stem_buffer_intersects","nearest"):
            if pd.isna(d): return "medium"
            return "medium" if float(d) <= NEAREST_THRESH_M else "none"
        return "none"

    best["confidence"] = [conf(mt, d) for mt, d in zip(best["match_type_c"], best["dist_m_c"])]

    # çıktılar
    OUT_DEDUP = f"{ANN_WS}/Tree_to_FieldSpecies_JOINED_dedup.csv"
    OUT_SAFE  = f"{ANN_WS}/Tree_to_FieldSpecies_JOINED_SAFE.csv"
    best.drop(columns=["geometry"], errors="ignore").to_csv(OUT_DEDUP, index=False)
    best[(best["confidence"].isin(["high","medium"])) & best["species"].notna()] \
        .drop(columns=["geometry"], errors="ignore").to_csv(OUT_SAFE, index=False)

    print("Kaydedildi:")
    print(" -", OUT_DEDUP)
    print(" -", OUT_SAFE)

    # kısa özet
    total_poly   = best["ann_index"].nunique()
    within_n     = int((best["match_type_c"]=="within").sum())
    nearcent_n   = int((best["match_type_c"]=="nearest_centroid").sum())
    bufint_n     = int((best["match_type_c"]=="stem_buffer_intersects").sum())
    nearest_n    = int((best["match_type_c"]=="nearest").sum())
    labeled_n    = int(best["species"].notna().sum())
    safe_n       = int(((best["confidence"].isin(["high","medium"])) & best["species"].notna()).sum())

    print(f"\nPoligon: {total_poly} | within:{within_n}  nearest_centroid:{nearcent_n}  buffer_intersects:{bufint_n}  nearest:{nearest_n}")
    print(f"Etiketli: {labeled_n} | SAFE (high/medium & species): {safe_n}")
else:
    print("joined yok, bu hücre atlandı.")
# Out:
# Kaydedildi:
#  - /content/drive/MyDrive/weecology-NeonTreeEvaluation-d0b90bc/annotations_with_species/Tree_to_FieldSpecies_JOINED_dedup.csv
#  - /content/drive/MyDrive/weecology-NeonTreeEvaluation-d0b90bc/annotations_with_species/Tree_to_FieldSpecies_JOINED_SAFE.csv
#
# Poligon: 221958 | within:2992  nearest_centroid:10  buffer_intersects:260  nearest:140
# Etiketli: 221958 | SAFE (high/medium & species): 3402

# %%
# ==== Tür raporları ====
# SAFE varsa onu kullanıyoruz yoksa DEDUP
SAFE = f"{ANN_WS}/Tree_to_FieldSpecies_JOINED_SAFE.csv"
DEDUP= f"{ANN_WS}/Tree_to_FieldSpecies_JOINED_dedup.csv"
path_in = SAFE if os.path.exists(SAFE) else (DEDUP if os.path.exists(DEDUP) else None)

if path_in is None:
    raise SystemExit("Rapor için SAFE/DEDUP bulunamadı.")

df = pd.read_csv(path_in, low_memory=False)
print("Kaynak:", os.path.basename(path_in), "| Satır:", len(df))

def pick_col(cands):
    for c in cands:
        if c in df.columns: return c
    return None

col_species = pick_col(["species","scientificName","scientificName_x","scientificName_y","taxonID"])
col_xml     = pick_col(["xml_file","source_xml","source_xml_x","source_xml_y","source","filename"])
col_rgb     = pick_col(["rgb_file","source_rgb","source_rgb_x","source_rgb_y","filename"])
col_match   = pick_col(["match_type_c","match_type","match_type_x","match_type_y"])
col_conf    = pick_col(["confidence"])
col_year    = pick_col(["year_ann","year_field"])
col_site    = pick_col(["site_ann","site_field"])

if not col_species:
    raise SystemExit("Tür kolonu bulunamadı (species/scientificName/taxonID).")

# xml & rgb "stem" oluştur (uzantısız gövde)
def stem(x):
    if pd.isna(x): return None
    b = os.path.basename(str(x))
    b = re.sub(r"\.(xml|tif|tiff)$", "", b, flags=re.IGNORECASE)
    return b

df["xml_file"] = df[col_xml].map(stem) if col_xml else None
df["rgb_file"] = df[col_rgb].map(stem) if col_rgb else None

labeled = df[df[col_species].notna()].copy()

# long & pivot tablolar
by_xml_species = labeled.groupby(["xml_file", col_species], dropna=False).size().reset_index(name="count") if "xml_file" in labeled.columns else pd.DataFrame()
by_rgb_species = labeled.groupby(["rgb_file", col_species], dropna=False).size().reset_index(name="count") if "rgb_file" in labeled.columns else pd.DataFrame()

pivot_xml = by_xml_species.pivot_table(index="xml_file", columns=col_species, values="count", fill_value=0, aggfunc="sum") if len(by_xml_species) else pd.DataFrame()
pivot_rgb = by_rgb_species.pivot_table(index="rgb_file", columns=col_species, values="count", fill_value=0, aggfunc="sum") if len(by_rgb_species) else pd.DataFrame()

xml_summary = (by_xml_species.groupby("xml_file")["count"].sum().reset_index().rename(columns={"count":"total_trees_labeled"})) if len(by_xml_species) else pd.DataFrame()
rgb_summary = (by_rgb_species.groupby("rgb_file")["count"].sum().reset_index().rename(columns={"count":"total_trees_labeled"})) if len(by_rgb_species) else pd.DataFrame()

top_species = labeled[col_species].value_counts().head(20).reset_index().rename(columns={"index":"species", col_species:"n"})

# opsiyonel ek
extra = {}
if col_match:
    extra["match_type_counts.csv"] = labeled[col_match].value_counts(dropna=False).rename_axis("match_type").reset_index(name="n")
if col_conf:
    extra["confidence_counts.csv"] = labeled[col_conf].value_counts(dropna=False).rename_axis("confidence").reset_index(name="n")
if col_year:
    extra["by_year_species.csv"] = labeled.groupby([col_year, col_species]).size().reset_index(name="count")
if col_site:
    extra["by_site_species.csv"] = labeled.groupby([col_site, col_species]).size().reset_index(name="count")

# Kaydet
p_xml_long  = os.path.join(REPORT_DIR, "per_xml_species_counts.csv")
p_rgb_long  = os.path.join(REPORT_DIR, "per_rgb_species_counts.csv")
p_xml_pivot = os.path.join(REPORT_DIR, "per_xml_species_pivot.csv")
p_rgb_pivot = os.path.join(REPORT_DIR, "per_rgb_species_pivot.csv")
p_xml_sum   = os.path.join(REPORT_DIR, "per_xml_summary.csv")
p_rgb_sum   = os.path.join(REPORT_DIR, "per_rgb_summary.csv")
p_top       = os.path.join(REPORT_DIR, "top20_species_overall.csv")

if len(by_xml_species): by_xml_species.to_csv(p_xml_long, index=False)
if len(by_rgb_species): by_rgb_species.to_csv(p_rgb_long, index=False)
if len(pivot_xml):      pivot_xml.to_csv(p_xml_pivot)
if len(pivot_rgb):      pivot_rgb.to_csv(p_rgb_pivot)
if len(xml_summary):    xml_summary.to_csv(p_xml_sum, index=False)
if len(rgb_summary):    rgb_summary.to_csv(p_rgb_sum, index=False)
top_species.to_csv(p_top, index=False)
for name, tbl in extra.items():
    tbl.to_csv(os.path.join(REPORT_DIR, name), index=False)

print("Raporlar kaydedildi:")
for p in [p_xml_long, p_rgb_long, p_xml_pivot, p_rgb_pivot, p_xml_sum, p_rgb_sum, p_top] + \
         [os.path.join(REPORT_DIR, n) for n in extra.keys()]:
    print(" -", p)

# Konsola kısa örnek
if len(by_xml_species):
    print("\n— by_xml_species örnek —")
    print(by_xml_species.head(10).to_string(index=False))
if len(xml_summary):
    print("\n— En çok 10 XML (etiketli ağaç sayısına göre) —")
    print(xml_summary.sort_values("total_trees_labeled", ascending=False).head(10).to_string(index=False))
print("\n— Top 15 tür —")
print(top_species.head(15).to_string(index=False))
# Out:
# Kaynak: Tree_to_FieldSpecies_JOINED_SAFE.csv | Satır: 3402
# Raporlar kaydedildi:
#  - /content/drive/MyDrive/weecology-NeonTreeEvaluation-d0b90bc/annotations_with_species/reports/per_xml_species_counts.csv
#  - /content/drive/MyDrive/weecology-NeonTreeEvaluation-d0b90bc/annotations_with_species/reports/per_rgb_species_counts.csv
#  - /content/drive/MyDrive/weecology-NeonTreeEvaluation-d0b90bc/annotations_with_species/reports/per_xml_species_pivot.csv
#  - /content/drive/MyDrive/weecology-NeonTreeEvaluation-d0b90bc/annotations_with_species/reports/per_rgb_species_pivot.csv
#  - /content/drive/MyDrive/weecology-NeonTreeEvaluation-d0b90bc/annotations_with_species/reports/per_xml_summary.csv
#  - /content/drive/MyDrive/weecology-NeonTreeEvaluation-d0b90bc/annotations_with_species/reports/per_rgb_summary.csv
#  - /content/drive/MyDrive/weecology-NeonTreeEvaluation-d0b90bc/annotations_with_species/reports/top20_species_overall.csv
#  - /content/drive/MyDrive/weecology-NeonTreeEvaluation-d0b90bc/annotations_with_species/reports/match_type_counts.csv
#  - /content/drive/MyDrive/weecology-NeonTreeEvaluation-d0b90bc/annotations_with_species/reports/confidence_counts.csv
#  - /content/drive/MyDrive/weecology-NeonTreeEvaluation-d0b90bc/annotations_with_species/reports/by_year_species.csv
#  - /content/drive/MyDrive/weecology-NeonTreeEvaluation-d0b90bc/annotations_with_species/reports/by_site_species.csv
#
# — by_xml_species örnek —
#      xml_file                            species  count
# BART_036_2019                     Acer rubrum L.     12
# BART_036_2019      Betula alleghaniensis Britton     13
# BART_036_2019            Fagus grandifolia Ehrh.     48
# BART_036_2019                 Picea rubens Sarg.      2
# BART_036_2019     Tsuga canadensis (L.) Carrière      1
# SJER_003_2018 Pinus sabiniana Douglas ex Douglas     30
# SJER_003_2018           Quercus wislizeni A. DC.     30
# SJER_004_2018           Quercus wislizeni A. DC.     10
# SJER_005_2018   Ceanothus cuneatus (Hook.) Nutt.     10
# SJER_010_2018 Pinus sabiniana Douglas ex Douglas     40
#
# — En çok 10 XML (etiketli ağaç sayısına göre) —
#      xml_file  total_trees_labeled
# TEAK_062_2018                  288
# TEAK_052_2018                  280
# TEAK_050_2018                  280
# TEAK_044_2018                  248
# TEAK_046_2018                  240
# TEAK_059_2018                  240
# TEAK_057_2018                  232
# TEAK_060_2018                  144
# TEAK_054_2018                  128
# TEAK_045_2018                  112
#
# — Top 15 tür —
#                                                  n  count
#                      Abies magnifica A. Murray bis   1008
#      Abies lowiana (Gordon & Glend.) A. Murray bis    864
#                   Pinus contorta Douglas ex Loudon    512
#                           Quercus wislizeni A. DC.    270
#                               Pinus jeffreyi Balf.    192
#                     Quercus douglasii Hook. & Arn.    170
#                 Pinus sabiniana Douglas ex Douglas    140
#                         Rhamnus ilicifolia Kellogg     50
#                            Fagus grandifolia Ehrh.     48
#                       Ceanothus leucodermis Greene     30
#                                       Pinaceae sp.     24
#                   Ceanothus cuneatus (Hook.) Nutt.     20
#                           Lupinus albifrons Benth.     20
# Abies concolor (Gord. & Glend.) Lindl. ex Hildebr.     16
#                      Betula alleghaniensis Britton     13

# %%
# ==== XML coverage ====
XMLS = glob.glob(os.path.join(ANN_DIR, "*.xml"))
print("XML dosyası sayısı:", len(XMLS))

# xml bazında toplam 'object' (poligon) say
rows = []
for f in XMLS:
    try:
        root = ET.parse(f).getroot()
        nobj = len(root.findall(".//object"))
    except Exception:
        nobj = 0
    rows.append({"xml_file": os.path.basename(f), "n_objects": nobj})
df_counts = pd.DataFrame(rows)
total_polys_ann = int(df_counts["n_objects"].sum())
print("Toplam poligon (annotations):", total_polys_ann)

# SAFE yükleme ve xml_file gövdesini üretme
SAFE = f"{ANN_WS}/Tree_to_FieldSpecies_JOINED_SAFE.csv"
if not os.path.exists(SAFE):
    raise SystemExit("SAFE bulunamadı, önce Cell 7'yi başarıyla üretmelisin.")

df_safe = pd.read_csv(SAFE, low_memory=False)

xml_cands = [c for c in ["xml_file","source_xml","source_xml_x","source_xml_y","source","filename","source_rgb","source_rgb_x","source_rgb_y"] if c in df_safe.columns]

def to_xml_name(v):
    if pd.isna(v): return None
    b = os.path.basename(str(v))
    if re.search(r"\.xml$", b, flags=re.IGNORECASE):
        return b
    # RGB isminden XML türet
    return re.sub(r"\.(tif|tiff)$", ".xml", b, flags=re.IGNORECASE)

if "xml_file" not in df_safe.columns:
    df_safe["xml_file"] = None
    for c in xml_cands:
        df_safe["xml_file"] = df_safe["xml_file"].fillna(df_safe[c].map(to_xml_name))
df_safe["xml_file"] = df_safe["xml_file"].fillna("UNKNOWN.xml")

safe_polys = len(df_safe)
coverage = 100.0 * safe_polys / total_polys_ann if total_polys_ann>0 else 0.0
print(f"Eşleşme oranı: {safe_polys}/{total_polys_ann} = %{coverage:.2f}")

# dosya bazlı coverage
by_file = df_safe["xml_file"].value_counts().rename_axis("xml_file").reset_index(name="safe_count")
df_merged = df_counts.merge(by_file, on="xml_file", how="left").fillna({"safe_count":0})
df_merged["safe_count"] = df_merged["safe_count"].astype(int)
df_merged["coverage_%"] = (df_merged["safe_count"] / df_merged["n_objects"] * 100).round(2)

# site bazlı coverage
def extract_site(s):
    m = re.search(r"\b([A-Z]{3,4})\b", str(s))
    return m.group(1) if m else "UNK"

df_merged["site"] = df_merged["xml_file"].map(extract_site)
site_cov = df_merged.groupby("site").agg(
    files=("xml_file","count"),
    ann_polys=("n_objects","sum"),
    safe_polys=("safe_count","sum")
).reset_index()
site_cov["coverage_%"] = (site_cov["safe_polys"] / site_cov["ann_polys"] * 100).round(2)

# Kaydet
out_per_file = os.path.join(REPORT_DIR, "coverage_per_file.csv")
out_per_site = os.path.join(REPORT_DIR, "coverage_per_site.csv")
df_merged.to_csv(out_per_file, index=False)
site_cov.to_csv(out_per_site, index=False)

print("\n Kaydedildi:")
print(" -", out_per_file)
print(" -", out_per_site)

print("\n— En yüksek kapsama oranına sahip 10 dosya —")
print(df_merged.sort_values("coverage_%", ascending=False).head(10).to_string(index=False))

print("\n— Site bazında özet —")
print(site_cov.sort_values("coverage_%", ascending=False).to_string(index=False))
# Out:
# XML dosyası sayısı: 227
# Toplam poligon (annotations): 31044
# Eşleşme oranı: 3402/31044 = %10.96
#
#  Kaydedildi:
#  - /content/drive/MyDrive/weecology-NeonTreeEvaluation-d0b90bc/annotations_with_species/reports/coverage_per_file.csv
#  - /content/drive/MyDrive/weecology-NeonTreeEvaluation-d0b90bc/annotations_with_species/reports/coverage_per_site.csv
#
# — En yüksek kapsama oranına sahip 10 dosya —
#          xml_file  n_objects  safe_count  coverage_% site
# SJER_004_2018.xml          1          10     1000.00  UNK
# TEAK_062_2018.xml         39         288      738.46  UNK
# SJER_050_2018.xml         15         110      733.33  UNK
# SJER_063_2018.xml         13          90      692.31  UNK
# TEAK_044_2018.xml         36         248      688.89  UNK
# SJER_003_2018.xml          9          60      666.67  UNK
# SJER_046_2018.xml         14          90      642.86  UNK
# TEAK_046_2018.xml         39         240      615.38  UNK
# TEAK_050_2018.xml         48         280      583.33  UNK
# SJER_021_2018.xml          4          20      500.00  UNK
#
# — Site bazında özet —
# site  files  ann_polys  safe_polys  coverage_%
#  UNK    227      31044        3402       10.96
